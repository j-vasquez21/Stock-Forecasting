# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
# important to set a keras random seed for reproducibility on the LSTM model
tf.keras.utils.set_random_seed(42)

from keras.models import Sequential
from keras.layers import Dense, LSTM

# Change to statsmodels.tsa.arima.model on jupyter notebook.
# statsmodels.tsa.arima_model for google colab
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from fbprophet import Prophet

import warnings
warnings.simplefilter('ignore')

plt.style.use("fivethirtyeight")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# for working on google colab 
# skip cell if working on jupyter notebook
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-927830e4-f819-4a4f-a9db-ca3c81aa59f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-927830e4-f819-4a4f-a9db-ca3c81aa59f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index_funds_data.csv to index_funds_data.csv

# %% [markdown]
# We begin by importing our funds csv and selecting the data for the ticker name of interest. The price that we will be focusing on will be the Close price of the fund, therefore we will only concern ourselves with the close column. We will also take the opportunity convert the date column into a datetime object.

# %%
# change path to '../data/index_funds_data.csv' if working on jupyter notebook

funds = pd.read_csv('index_funds_data.csv')
funds['date'] = pd.to_datetime(funds['date'],infer_datetime_format=True)
funds = funds[['symbol','date','close']]
funds = funds.set_index(['symbol','date'])
SPY = funds.loc['SPY',['close']]

# %% [markdown]
# ### Visualize The Closing Price
#
# Below we plot the time series for the fund to get an initial look at what the series looks like.

# %%
plt.figure(figsize=(16,8))
plt.plot(SPY['close'])
plt.title("Close Price History")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.show()

# %% [markdown]
# ### Baseline "Naive" Model

# %% [markdown]
# To set up a baseline model, we shift the time series by 100 days forward. This is known a naive forecast. By shifting the time series, we are using the shifted series to represent our predictions of the closing price.

# %%
SPY_baseline = SPY.shift(100)
SPY_base_rmse = mean_squared_error(SPY[100:],SPY_baseline[100:],squared=False)
SPY_base_rmse
# Out:
# 26.6817295541724

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.set_title("Baseline Forecast")
ax.plot(SPY,c='b',label='Actual')
ax.plot(SPY_baseline,c='r',label='Baseline')
plt.legend()
plt.show()

# %% [markdown]
# To test the performance of our baseline we decide on a cutoff to split our original time series into the train set and test set. We also split the time series of our baseline using the same cutoff to create a the train predictions and test predictions. Next we calculate the RMSE of the baseline using the test predictions and the actual values, which is the test set from the original time series.

# %%
new_df = pd.DataFrame()
new_df['original'] = SPY['close']
new_df['shifted'] = SPY['close'].shift(100)
cutoff = int(len(new_df['original']) * 0.80)
original = new_df['original']
shifted = new_df['shifted']
original_train, original_test = original[100:cutoff], original[cutoff:]
shifted_train, shifted_test = shifted[100:cutoff], shifted[cutoff:]

# %%
baseline_rmse = mean_squared_error(original_train,shifted_train,squared=False)
baseline_rmse
# Out:
# 25.613166873347474

# %% [markdown]
# To help visualize the results from the baseline, we plot each set below.

# %%
plt.figure(figsize=(10,4))
plt.title('SPY Baseline Forecast')
plt.plot(original_train,label='Train')
plt.plot(original_test,c='r',label='Actual')
plt.plot(shifted_test,c='blue',label='Baseline Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA Modeling
# Next, we move on to the next modeling techinique. We have defined various helper functions below to help us with the ARIMA modeling process.
#
# As we recall from the EDA notebook, the time series is not stationary to begin with. By applying differencing, we were able to convert the time series into a stationary one. This means we can expect to have an ARIMA model with at least a first order differencing.

# %%
# Arima Helper Functions

# get all possible combinations of (p,d,q) for a range (n,k)
def get_combos(n,k):
    p = d = q = range(n, k)
    pdq = list(itertools.product(p, d, q))
    pdqs = [(x[0], x[1], x[2]) for x in list(itertools.product(p, d, q))]
    return pdqs

# find the optimal order for arima model for a series
def get_optimal_params(ts,n,k):
    pdq = get_combos(n,k)
    ans = []
    for comb in pdq:
        try:
            model = ARIMA(ts,
                         order=comb)
            output = model.fit()
            ans.append([comb,output.aic])
        except:
            continue
    ans_df = pd.DataFrame(ans, columns=['pdq','aic'])
    optimals = ans_df.loc[ans_df['aic'].idxmin()]
    return optimals

# fit arima model
def arima_models(ts,n,k):
    order = get_optimal_params(ts,n,k)['pdq']
    model = ARIMA(ts,
                 order=order)
    output = model.fit()
    return output

# time series train test split
def train_test_splt(ts,test_size):
    cutoff = int(ts.shape[0]*(1-test_size))
    train = ts[:cutoff]
    test = ts[cutoff:]
    return train, test

def find_rmse(model, test_data):
    y_hat = model.predict(start=test_data.index[0], end=test_data.index[-1], typ='levels')
    return y_hat, np.sqrt(mean_squared_error(test_data, y_hat))

# %%
SPY_train, SPY_test = train_test_splt(SPY,.2)

# Find optimal pdq
print(get_optimal_params(SPY_train,0,3))

# Fit ARIMA with optimal pdq
arima_model = arima_models(SPY_train,0,3)

# Summary of model
arima_model.summary()
# Out:
# pdq    (2, 1, 2)
# aic      7202.28
# Name: 22, dtype: object
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                 1459
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -3595.142
# Method:                       css-mle   S.D. of innovations              2.843
# Date:                Wed, 26 Jan 2022   AIC                           7202.285
# Time:                        09:27:41   BIC                           7233.998
# Sample:                    01-13-2017   HQIC                          7214.115
#                          - 01-10-2021
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1043      0.071      1.470      0.142      -0.035       0.243
# ar.L1.D.close    -1.8264      0.023    -78.412      0.000      -1.872      -1.781
# ar.L2.D.close    -0.8920      0.023    -39.069      0.000      -0.937      -0.847
# ma.L1.D.close     1.7495      0.031     56.496      0.000       1.689       1.810
# ma.L2.D.close     0.7933      0.030     26.799      0.000       0.735       0.851
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0238           -0.2701j            1.0588           -0.4589
# AR.2           -1.0238           +0.2701j            1.0588            0.4589
# MA.1           -1.1027           -0.2111j            1.1228           -0.4699
# MA.2           -1.1027           +0.2111j            1.1228            0.4699
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# Looking at the ARIMA summary table, we can see that the model did in fact apply differencing to our model. Our p-values on our coefficients are low enough, which tell us that they are significant. After an iterative search for the best parameter, this is the best fitting ARIMA model with the lowest AIC score.

# %% [markdown]
# Next we will calculate the RMSE for this model to evaluate it's performance.

# %%
yhat ,arima_rmse = find_rmse(arima_model,SPY_test)

# %%
arima_rmse
# Out:
# 35.73562207205963

# %% [markdown]
# Now we can plot the forecast to visually see how off or close our predictions are to the test data.

# %%
plt.figure(figsize=(15,4))
plt.title('ARIMA model SPY Forecast')
plt.xlabel('Date')
plt.ylabel('Close Price in USD ($)')
plt.plot(SPY_train,c="blue",label='Train')
plt.plot(SPY_test,c='green',label='Actual')
plt.plot(yhat, c='red',label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# Our next modeling technique will be the LSTM model. This is a special type of RNN that are especially useful for time series data.

# %%
data = SPY.filter(['close'])
dataset = data.values
cutoff = int(len(dataset)*0.8)
cutoff
# Out:
# 1460

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01405244],
#        [0.01609359],
#        [0.01295337],
#        ...,
#        [0.95211179],
#        [0.95211179],
#        [0.95211179]])

# %%
# create scaled training set
train_data = scaled_data[0:cutoff,:]
X_train = []
y_train = []

for i in range(100,len(train_data)):
    X_train.append(train_data[i-100:i,0])
    y_train.append(train_data[i,0])

# %%
# convert X_train and y_train to numpy arrays for training the model
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# reshape X_train for LSTM model
print(X_train.shape)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (1360, 100)
# (1360, 100, 1)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model
model.fit(X_train, y_train, batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 7s 90ms/step - loss: 0.0059
# Epoch 2/100
# 43/43 [==============================] - 4s 89ms/step - loss: 7.7736e-04
# Epoch 3/100
# 43/43 [==============================] - 4s 89ms/step - loss: 6.7238e-04
# Epoch 4/100
# 43/43 [==============================] - 4s 91ms/step - loss: 6.3577e-04
# Epoch 5/100
# 43/43 [==============================] - 4s 91ms/step - loss: 5.8642e-04
# Epoch 6/100
# 43/43 [==============================] - 4s 89ms/step - loss: 5.1643e-04
# Epoch 7/100
# 43/43 [==============================] - 4s 91ms/step - loss: 4.8600e-04
# Epoch 8/100
# 43/43 [==============================] - 4s 89ms/step - loss: 5.0378e-04
# Epoch 9/100
# 43/43 [==============================] - 4s 91ms/step - loss: 4.2926e-04
# Epoch 10/100
# 43/43 [==============================] - 5s 108ms/step - loss: 4.6717e-04
# Epoch 11/100
# 43/43 [==============================] - 4s 92ms/step - loss: 4.2515e-04
# Epoch 12/100
# 43/43 [==============================] - 4s 90ms/step - loss: 3.8361e-04
# Epoch 13/100
# 43/43 [==============================] - 4s 92ms/step - loss: 3.6877e-04
# Epoch 14/100
# 43/43 [==============================] - 4s 91ms/step - loss: 3.8747e-04
# Epoch 15/100
# 43/43 [==============================] - 4s 104ms/step - loss: 3.5841e-04
# Epoch 16/100
# 43/43 [==============================] - 4s 90ms/step - loss: 3.5455e-04
# Epoch 17/100
# 43/43 [==============================] - 4s 91ms/step - loss: 3.3025e-04
# Epoch 18/100
# 43/43 [==============================] - 4s 91ms/step - loss: 3.2783e-04
# Epoch 19/100
# 43/43 [==============================] - 4s 91ms/step - loss: 3.1764e-04
# Epoch 20/100
# 43/43 [==============================] - 4s 91ms/step - loss: 3.6193e-04
# Epoch 21/100
# 43/43 [==============================] - 4s 91ms/step - loss: 3.3039e-04
# Epoch 22/100
# 43/43 [==============================] - 4s 90ms/step - loss: 3.8979e-04
# Epoch 23/100
# 43/43 [==============================] - 5s 127ms/step - loss: 3.1187e-04
# Epoch 24/100
# 43/43 [==============================] - 4s 91ms/step - loss: 2.8198e-04
# Epoch 25/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.7746e-04
# Epoch 26/100
# 43/43 [==============================] - 4s 93ms/step - loss: 2.7445e-04
# Epoch 27/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.8474e-04
# Epoch 28/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.5825e-04
# Epoch 29/100
# 43/43 [==============================] - 5s 119ms/step - loss: 2.6874e-04
# Epoch 30/100
# 43/43 [==============================] - 4s 91ms/step - loss: 2.7941e-04
# Epoch 31/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.4352e-04
# Epoch 32/100
# 43/43 [==============================] - 4s 90ms/step - loss: 2.5967e-04
# Epoch 33/100
# 43/43 [==============================] - 4s 90ms/step - loss: 2.3932e-04
# Epoch 34/100
# 43/43 [==============================] - 4s 93ms/step - loss: 2.3565e-04
# Epoch 35/100
# 43/43 [==============================] - 4s 91ms/step - loss: 2.4438e-04
# Epoch 36/100
# 43/43 [==============================] - 4s 93ms/step - loss: 2.2159e-04
# Epoch 37/100
# 43/43 [==============================] - 4s 93ms/step - loss: 2.1322e-04
# Epoch 38/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.2993e-04
# Epoch 39/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.1614e-04
# Epoch 40/100
# 43/43 [==============================] - 4s 92ms/step - loss: 2.1905e-04
# Epoch 41/100
# 43/43 [==============================] - 4s 94ms/step - loss: 2.1730e-04
# Epoch 42/100
# 43/43 [==============================] - 4s 96ms/step - loss: 1.9554e-04
# Epoch 43/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.9609e-04
# Epoch 44/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.9966e-04
# Epoch 45/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.8846e-04
# Epoch 46/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.8413e-04
# Epoch 47/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.7981e-04
# Epoch 48/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.8863e-04
# Epoch 49/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.9960e-04
# Epoch 50/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.9310e-04
# Epoch 51/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.8246e-04
# Epoch 52/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.8779e-04
# Epoch 53/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.7038e-04
# Epoch 54/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6832e-04
# Epoch 55/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.9001e-04
# Epoch 56/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.7621e-04
# Epoch 57/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6055e-04
# Epoch 58/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.6866e-04
# Epoch 59/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6357e-04
# Epoch 60/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5803e-04
# Epoch 61/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.7753e-04
# Epoch 62/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6186e-04
# Epoch 63/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6335e-04
# Epoch 64/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.6158e-04
# Epoch 65/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5201e-04
# Epoch 66/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.4982e-04
# Epoch 67/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.9066e-04
# Epoch 68/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5902e-04
# Epoch 69/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.7070e-04
# Epoch 70/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6840e-04
# Epoch 71/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.4742e-04
# Epoch 72/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5194e-04
# Epoch 73/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5900e-04
# Epoch 74/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.5278e-04
# Epoch 75/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5978e-04
# Epoch 76/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.6439e-04
# Epoch 77/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6678e-04
# Epoch 78/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.4885e-04
# Epoch 79/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.6068e-04
# Epoch 80/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.4942e-04
# Epoch 81/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5461e-04
# Epoch 82/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5579e-04
# Epoch 83/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6536e-04
# Epoch 84/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.6246e-04
# Epoch 85/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.5207e-04
# Epoch 86/100
# 43/43 [==============================] - 4s 94ms/step - loss: 1.6927e-04
# Epoch 87/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5083e-04
# Epoch 88/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5908e-04
# Epoch 89/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5636e-04
# Epoch 90/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.6226e-04
# Epoch 91/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.5127e-04
# Epoch 92/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.5169e-04
# Epoch 93/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5304e-04
# Epoch 94/100
# 43/43 [==============================] - 4s 90ms/step - loss: 1.6289e-04
# Epoch 95/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.5614e-04
# Epoch 96/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.5131e-04
# Epoch 97/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.5866e-04
# Epoch 98/100
# 43/43 [==============================] - 4s 91ms/step - loss: 1.4725e-04
# Epoch 99/100
# 43/43 [==============================] - 4s 93ms/step - loss: 1.6433e-04
# Epoch 100/100
# 43/43 [==============================] - 4s 92ms/step - loss: 1.5413e-04

# %%
# creating test data
test_data = scaled_data[cutoff-100:,:]
X_test = []
y_test = dataset[cutoff:,:]

for i in range(100,len(test_data)):
    X_test.append(test_data[i-100:i, 0])

# %%
# convert X_test to numpy array
X_test = np.array(X_test)

# %%
# reshape X_test for LSTM model
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# get model preds
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
# get rmse
lstm_rmse = mean_squared_error(y_test,predictions,squared=False)
lstm_rmse
# Out:
# 4.413671812061644

# %%
# plot the data
train = data[:cutoff]
actual = data[cutoff:]

actual['Predictions'] = predictions

# %%
# visualize 
plt.figure(figsize=(16,8))
plt.title("Model Forecast For SPY")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.plot(train['close'])
plt.plot(actual['close'])
plt.plot(actual['Predictions'])
plt.legend(['Train','Actual','Predictions'],loc='lower right')
plt.show()

# %% [markdown]
# ### FBprophet Model

# %%
# Fbprophet Helper functions

# formats dataframe to meet fbprophet requirements
def prep_dataframe(df):
    ts = df.copy()
    ts.rename(columns={'close':'y'},inplace=True)
    ts.index.name = 'ds'
    ts = ts.reset_index()
    ts['ds'] = ts['ds'].apply(lambda x: x.replace(tzinfo=None))
    return ts

# creates training and test set and fit the prophet model
def fit_train(data,prepared=True):
    # Format dataframe to fbprophet requirements in not already done
    if prepared == False:
        data = prep_dataframe(data)

    # Train-Test Split
    cutoff = int(data.shape[0] * 0.80)
    train = data.iloc[:cutoff]
    test = data.iloc[cutoff:]

    # Fit the model
    mod = Prophet(interval_width=0.95,weekly_seasonality=True,daily_seasonality=True)
    fitted_mod = mod.fit(train)

    if prepared == False:
        return fitted_mod, data, train, test
    else:
        return fitted_mod, train, test

# creates predictions using fitted model
def get_preds(model,test_data):
    preds = model.predict(test_data[['ds']])
    return preds[['ds','yhat_lower','yhat_upper','yhat']]

def get_rmse(preds, test_data):
    return mean_squared_error(preds['yhat'],test_data['y'],squared=False)

# %%
mod, SPY_prepped, train, test = fit_train(SPY,False)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
predictions = get_preds(mod,test)

# %%
fbprophet_rmse = get_rmse(predictions,test)

# %%
fbprophet_rmse
# Out:
# 35.48411133489759

# %%
train = train.set_index('ds')
test = test.set_index('ds')

# %%
predictions = predictions[['ds','yhat']].set_index('ds')

# %%
plt.figure(figsize=(15,5))
plt.title('FBprophet Forecast For SPY')
plt.xlabel('Date')
plt.ylabel("Close Price in USD ($)")
plt.plot(train['y'],label="train")
plt.plot(test['y'],c='green',label='actual')
plt.plot(predictions['yhat'],c='red',label='predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation of Models
#
# Judging the models based on the RMSE, we can say that the LSTM model was the best performing model since it yields the lowest RMSE. This means that the LSTM model will give us the most reliable predictions.
#
# Our RMSE for the LSTM model tells us that we can expect our close price predictions to be off, on average, by $4.41.

# %%
rmses = pd.Series( [baseline_rmse, arima_rmse, lstm_rmse, fbprophet_rmse], index=['Baseline','ARIMA','LSTM','FBprophet'])
rmses = pd.DataFrame(rmses,columns=['SPY_RMSEs'])
rmses = rmses.reset_index()
rmses.columns = ['Model','SPY_RMSEs']
rmses
# Out:
#        Model  SPY_RMSEs
# 0   Baseline  25.613167
# 1      ARIMA  35.735622
# 2       LSTM   4.413672
# 3  FBprophet  35.484111

# %% [markdown]
# The next lines are used to create the model_rmses.csv file that will be used in the Evaluation Notebook. No need to rerun the next lines.

# %%
# from google.colab import drive
# drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# rmses_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')
# rmses_df = rmses_df.drop('Unnamed: 0',axis=1)
# rmses_df = pd.concat([rmses_df,rmses[['SPY_RMSEs']]],axis=1)
# rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  VUG_RMSEs  DIA_RMSEs  SPY_RMSEs
# 0   Baseline     2.047809  25.747396  ...  18.027399  22.877579  25.613167
# 1      ARIMA     2.292706  36.026600  ...  21.115098  20.143136  35.735622
# 2       LSTM     0.432891   4.124593  ...   3.685428   2.945879   4.413672
# 3  FBprophet     5.670109  32.488233  ...  41.450437  24.605617  35.484111
#
# [4 rows x 12 columns]

# %%
# rmses_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')

# %% [markdown]
# ### Forecasting Future Closing Prices
#
# Now that we have found our best working model, we will use it to find the close prices for the rest of 2022 to and calculate the ROI from the current day to the last forecasted day.

# %%
X_test[-1].shape
# Out:
# (100, 1)

# %%
# daily close price predictions for the next year
future_predictions = []

last_100_days = X_test[-1] # real

while len(future_predictions) != 365:
    # reshape the input array for the lstm model
    X = np.reshape(last_100_days, (last_100_days.shape[1], last_100_days.shape[0], 1))
    # make one new prediction
    forecast = model.predict(X) 
    # update last_100_days dropping first value and adding the new prediction to the end of the array
    new = np.concatenate((last_100_days, forecast))
    last_100_days = new[1:]
    # append unscaled prediction to future predictions
    future_predictions.append(scaler.inverse_transform(forecast)[0])

# %%
len(future_predictions)
# Out:
# 365

# %%
predictions_df = pd.DataFrame(future_predictions,columns=['close'])
SPY_copy = SPY.copy()
SPY_copy = SPY.reset_index()
SPY_copy['date'] = SPY_copy['date'].apply(lambda x: x.replace(tzinfo=None))
SPY_copy
# Out:
#            date       close
# 0    2017-01-12  226.529999
# 1    2017-01-13  227.050003
# 2    2017-01-14  226.250000
# 3    2017-01-15  226.250000
# 4    2017-01-16  226.250000
# ...         ...         ...
# 1820 2022-01-06  467.940000
# 1821 2022-01-07  466.090000
# 1822 2022-01-08  465.510000
# 1823 2022-01-09  465.510000
# 1824 2022-01-10  465.510000
#
# [1825 rows x 2 columns]

# %%
# getting dates for the next 60 days

from datetime import datetime, timedelta

def date_range(start, end):
    delta = end - start  # as timedelta
    days = [start + timedelta(days=i) for i in range(delta.days + 1)]
    return days

# last date from the data
start_date = SPY_copy.iloc[-1,0]

end_date = datetime(2023, 1, 10)
    
future_dates = date_range(start_date, end_date)[1:]
len(future_dates)
# Out:
# 365

# %%
# Create new dataframe with next 365 day close price predictions 
predictions_df['date'] = future_dates
predictions_df = predictions_df[['date','close']]
SPY_copy_2 = pd.concat([SPY_copy,predictions_df])
# Final dataframe with old data and next 365 day predictions
SPY_copy_2 = SPY_copy_2.set_index('date')

# %%
SPY_copy_2.head()
# Out:
#                  close
# date
# 2017-01-12  226.529999
# 2017-01-13  227.050003
# 2017-01-14  226.250000
# 2017-01-15  226.250000
# 2017-01-16  226.250000

# %%
SPY_copy_2.iloc[-366]
# Out:
# close    465.51
# Name: 2022-01-10 00:00:00, dtype: float64

# %%
# Find the ROI for the next 365 days
ROI_next_365_days = (SPY_copy_2.iloc[-1] - SPY_copy_2.iloc[-366]) / SPY_copy_2.iloc[-366]
ROI_df = pd.DataFrame(ROI_next_365_days, columns=['SPY_ROI'])
print(f"Next 365 days ROI: {round(ROI_next_365_days[0]*100,2)}%")
# Out:
# Next 365 days ROI: 42.41%

# %% [markdown]
# The next lines are used to create the rois.csv file that will be used in the Evaluation Notebook. No need to rerun the next lines.

# %%
# roi_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
# roi_df = roi_df.drop('Unnamed: 0',axis=1)
# roi_df['SPY_ROI'] = ROI_next_365_days.values
# roi_df
# Out:
#    NASDX_ROI  IVV_ROI  VFIAX_ROI  ...   VUG_ROI   DIA_ROI   SPY_ROI
# 0   0.267214  0.33298   0.400738  ...  0.293362  0.185695  0.424128
#
# [1 rows x 11 columns]

# %%
# roi_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
