# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
# important to set a keras random seed for reproducibility on the LSTM model
tf.keras.utils.set_random_seed(42)

from keras.models import Sequential
from keras.layers import Dense, LSTM

# Change to statsmodels.tsa.arima.model on jupyter notebook.
# statsmodels.tsa.arima_model for google colab
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from fbprophet import Prophet

import warnings
warnings.simplefilter('ignore')

plt.style.use("fivethirtyeight")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# uploading csv file on google colab 
# skip cell if working on jupyter notebook

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4fd5fc54-0bb5-4530-bd0b-ad49e25c8bcb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fd5fc54-0bb5-4530-bd0b-ad49e25c8bcb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index_funds_data.csv to index_funds_data.csv

# %% [markdown]
# We begin by importing our funds csv and selecting the data for the ticker name of interest. The price that we will be focusing on will be the Close price of the fund, therefore we will only concern ourselves with the close column. We will also take the opportunity convert the date column into a datetime object.

# %%
# change the file path to "./data/index_funds_data.csv" if working on jupyter notebook

funds = pd.read_csv('index_funds_data.csv')
funds['date'] = pd.to_datetime(funds['date'],infer_datetime_format=True)
funds = funds[['symbol','date','close']]
funds = funds.set_index(['symbol','date'])
SWPPX = funds.loc['SWPPX',['close']]

# %% [markdown]
# ### Visualize The Closing Price
#
# Below we plot the time series for the fund to get an initial look at what the series looks like.

# %%
plt.figure(figsize=(16,8))
plt.plot(SWPPX['close'])
plt.title("Close Price History")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.show()

# %% [markdown]
# ### Baseline "Naive" Model

# %% [markdown]
# To set up a baseline model, we shift the time series by 60 days forward. This is known a naive forecast.

# %%
SWPPX_baseline = SWPPX.shift(60)
SWPPX_base_rmse = mean_squared_error(SWPPX[60:],SWPPX_baseline[60:],squared=False)
SWPPX_base_rmse
# Out:
# 3.203442571039632

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.set_title("Baseline Forecast")
ax.plot(SWPPX,c='b',label='Actual')
ax.plot(SWPPX_baseline,c='r',label='Baseline')
plt.legend()
plt.show()

# %% [markdown]
# To test the performance of our baseline we decide on a cutoff to split our original time series into the train set and test set. We also split the time series of our baseline using the same cutoff to create a the train predictions and test predictions. Next we calculate the RMSE of the baseline using the test predictions and the actual values, which is the test set from the original time series.

# %%
new_df = pd.DataFrame()
new_df['original'] = SWPPX['close']
new_df['shifted'] = SWPPX['close'].shift(60)
cutoff = int(len(new_df['original']) * 0.80)
original = new_df['original']
shifted = new_df['shifted']
original_train, original_test = original[60:cutoff], original[cutoff:]
shifted_train, shifted_test = shifted[60:cutoff], shifted[cutoff:]

# %%
baseline_rmse = mean_squared_error(original_train,shifted_train,squared=False)
baseline_rmse
# Out:
# 3.2675619351436938

# %% [markdown]
# To help visualize the results from the baseline, we plot each set below.

# %%
plt.figure(figsize=(10,4))
plt.title('SWPPX Baseline Forecast')
plt.plot(original_train,label='Train')
plt.plot(original_test,c='r',label='Actual')
plt.plot(shifted_test,c='blue',label='Baseline Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA Modeling
# Next, we move on to the next modeling techinique. We have defined various helper functions below to help us with the ARIMA modeling process.
#
# As we recall from the EDA notebook, the time series is not stationary to begin with. Applying differencing was able to convert the time series to a stationary one. So we can expect to have an ARIMA model with at least a first order differencing.

# %%
# Arima Helper Functions

# get all possible combinations of (p,d,q) for a range (n,k)
def get_combos(n,k):
    p = d = q = range(n, k)
    pdq = list(itertools.product(p, d, q))
    pdqs = [(x[0], x[1], x[2]) for x in list(itertools.product(p, d, q))]
    return pdqs

# find the optimal order for arima model for a series
def get_optimal_params(ts,n,k):
    pdq = get_combos(n,k)
    ans = []
    for comb in pdq:
        try:
            model = ARIMA(ts,
                         order=comb)
            output = model.fit()
            ans.append([comb,output.aic])
        except:
            continue
    ans_df = pd.DataFrame(ans, columns=['pdq','aic'])
    optimals = ans_df.loc[ans_df['aic'].idxmin()]
    return optimals

# fit arima model
def arima_models(ts,n,k):
    order = get_optimal_params(ts,n,k)['pdq']
    model = ARIMA(ts,
                 order=order)
    output = model.fit()
    return output

# time series train test split
def train_test_splt(ts,test_size):
    cutoff = int(ts.shape[0]*(1-test_size))
    train = ts[:cutoff]
    test = ts[cutoff:]
    return train, test

def find_rmse(model, test_data):
    y_hat = model.predict(start=test_data.index[0], end=test_data.index[-1], typ='levels')
    return y_hat, np.sqrt(mean_squared_error(test_data, y_hat))

# %%
SWPPX_train, SWPPX_test = train_test_splt(SWPPX,.2)

# Find optimal pdq
print(get_optimal_params(SWPPX_train,0,3))

# Fit ARIMA with optimal pdq
arima_model = arima_models(SWPPX_train,0,3)

# Summary of model
arima_model.summary()
# Out:
# pdq    (2, 1, 2)
# aic       1842.7
# Name: 22, dtype: object
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                 1459
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -915.351
# Method:                       css-mle   S.D. of innovations              0.453
# Date:                Mon, 24 Jan 2022   AIC                           1842.702
# Time:                        19:58:33   BIC                           1874.415
# Sample:                    01-13-2017   HQIC                          1854.533
#                          - 01-10-2021
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0159      0.011      1.418      0.156      -0.006       0.038
# ar.L1.D.close    -1.8233      0.024    -75.560      0.000      -1.871      -1.776
# ar.L2.D.close    -0.8922      0.027    -32.970      0.000      -0.945      -0.839
# ma.L1.D.close     1.7263      0.031     55.002      0.000       1.665       1.788
# ma.L2.D.close     0.7804      0.034     23.153      0.000       0.714       0.846
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0218           -0.2770j            1.0587           -0.4579
# AR.2           -1.0218           +0.2770j            1.0587            0.4579
# MA.1           -1.1060           -0.2410j            1.1320           -0.4659
# MA.2           -1.1060           +0.2410j            1.1320            0.4659
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# Looking at the ARIMA summary table, we can see that the model did in fact apply differencing to our model. Our p-values on our coefficients are low enough, which tell us that they are significant. After an iterative search for the best parameter, this is the best fitting ARIMA model with the lowest AIC score.

# %% [markdown]
# Next we will calculate the RMSE for this model to evaluate it's performance.

# %%
yhat ,arima_rmse = find_rmse(arima_model,SWPPX_test)

# %%
arima_rmse
# Out:
# 5.8908457127586065

# %%
plt.figure(figsize=(15,4))
plt.title('ARIMA model SWPPX Forecast')
plt.xlabel('Date')
plt.ylabel('Close Price in USD ($)')
plt.plot(SWPPX_train,c="blue",label='Train')
plt.plot(SWPPX_test,c='green',label='Actual')
plt.plot(yhat, c='red',label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# Our next modeling technique will be the LSTM model. This is a special type of RNN.

# %%
data = SWPPX.filter(['close'])
dataset = data.values
cutoff = int(len(dataset)*0.8)
cutoff
# Out:
# 1460

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01459667],
#        [0.01638924],
#        [0.01357234],
#        ...,
#        [0.95134443],
#        [0.95134443],
#        [0.95134443]])

# %%
# create scaled training set
train_data = scaled_data[0:cutoff,:]
X_train = []
y_train = []

for i in range(100,len(train_data)):
    X_train.append(train_data[i-100:i,0])
    y_train.append(train_data[i,0])

# %%
# convert X_train and y_train to numpy arrays for training the model
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# reshape X_train for LSTM model
print(X_train.shape)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (1360, 100)
# (1360, 100, 1)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model
model.fit(X_train, y_train, batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 8s 100ms/step - loss: 0.0061
# Epoch 2/100
# 43/43 [==============================] - 4s 100ms/step - loss: 7.8586e-04
# Epoch 3/100
# 43/43 [==============================] - 4s 100ms/step - loss: 6.9080e-04
# Epoch 4/100
# 43/43 [==============================] - 4s 100ms/step - loss: 6.6316e-04
# Epoch 5/100
# 43/43 [==============================] - 4s 102ms/step - loss: 5.8610e-04
# Epoch 6/100
# 43/43 [==============================] - 4s 99ms/step - loss: 5.2821e-04
# Epoch 7/100
# 43/43 [==============================] - 4s 99ms/step - loss: 5.0358e-04
# Epoch 8/100
# 43/43 [==============================] - 4s 104ms/step - loss: 5.1381e-04
# Epoch 9/100
# 43/43 [==============================] - 4s 101ms/step - loss: 4.3823e-04
# Epoch 10/100
# 43/43 [==============================] - 4s 104ms/step - loss: 4.8126e-04
# Epoch 11/100
# 43/43 [==============================] - 4s 101ms/step - loss: 4.3386e-04
# Epoch 12/100
# 43/43 [==============================] - 5s 105ms/step - loss: 3.9327e-04
# Epoch 13/100
# 43/43 [==============================] - 5s 105ms/step - loss: 3.8119e-04
# Epoch 14/100
# 43/43 [==============================] - 4s 104ms/step - loss: 3.8927e-04
# Epoch 15/100
# 43/43 [==============================] - 7s 163ms/step - loss: 3.7503e-04
# Epoch 16/100
# 43/43 [==============================] - 5s 107ms/step - loss: 3.6972e-04
# Epoch 17/100
# 43/43 [==============================] - 4s 103ms/step - loss: 3.4190e-04
# Epoch 18/100
# 43/43 [==============================] - 4s 100ms/step - loss: 3.3495e-04
# Epoch 19/100
# 43/43 [==============================] - 4s 102ms/step - loss: 3.3238e-04
# Epoch 20/100
# 43/43 [==============================] - 4s 101ms/step - loss: 3.6776e-04
# Epoch 21/100
# 43/43 [==============================] - 4s 100ms/step - loss: 3.3801e-04
# Epoch 22/100
# 43/43 [==============================] - 4s 100ms/step - loss: 4.0383e-04
# Epoch 23/100
# 43/43 [==============================] - 4s 104ms/step - loss: 3.2911e-04
# Epoch 24/100
# 43/43 [==============================] - 4s 100ms/step - loss: 2.9350e-04
# Epoch 25/100
# 43/43 [==============================] - 4s 99ms/step - loss: 2.8819e-04
# Epoch 26/100
# 43/43 [==============================] - 4s 101ms/step - loss: 2.8492e-04
# Epoch 27/100
# 43/43 [==============================] - 4s 100ms/step - loss: 2.9754e-04
# Epoch 28/100
# 43/43 [==============================] - 4s 100ms/step - loss: 2.6982e-04
# Epoch 29/100
# 43/43 [==============================] - 4s 101ms/step - loss: 2.8238e-04
# Epoch 30/100
# 43/43 [==============================] - 4s 104ms/step - loss: 2.9170e-04
# Epoch 31/100
# 43/43 [==============================] - 5s 109ms/step - loss: 2.5366e-04
# Epoch 32/100
# 43/43 [==============================] - 5s 105ms/step - loss: 2.7782e-04
# Epoch 33/100
# 43/43 [==============================] - 5s 106ms/step - loss: 2.5195e-04
# Epoch 34/100
# 43/43 [==============================] - 5s 108ms/step - loss: 2.4979e-04
# Epoch 35/100
# 43/43 [==============================] - 4s 104ms/step - loss: 2.5661e-04
# Epoch 36/100
# 43/43 [==============================] - 4s 100ms/step - loss: 2.3292e-04
# Epoch 37/100
# 43/43 [==============================] - 5s 105ms/step - loss: 2.2555e-04
# Epoch 38/100
# 43/43 [==============================] - 5s 105ms/step - loss: 2.4396e-04
# Epoch 39/100
# 43/43 [==============================] - 5s 106ms/step - loss: 2.2690e-04
# Epoch 40/100
# 43/43 [==============================] - 4s 102ms/step - loss: 2.2819e-04
# Epoch 41/100
# 43/43 [==============================] - 4s 103ms/step - loss: 2.2419e-04
# Epoch 42/100
# 43/43 [==============================] - 4s 102ms/step - loss: 2.1141e-04
# Epoch 43/100
# 43/43 [==============================] - 4s 104ms/step - loss: 2.1098e-04
# Epoch 44/100
# 43/43 [==============================] - 4s 103ms/step - loss: 2.1136e-04
# Epoch 45/100
# 43/43 [==============================] - 4s 103ms/step - loss: 2.0245e-04
# Epoch 46/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.9392e-04
# Epoch 47/100
# 43/43 [==============================] - 4s 98ms/step - loss: 1.8879e-04
# Epoch 48/100
# 43/43 [==============================] - 4s 101ms/step - loss: 2.0251e-04
# Epoch 49/100
# 43/43 [==============================] - 4s 102ms/step - loss: 2.1441e-04
# Epoch 50/100
# 43/43 [==============================] - 4s 103ms/step - loss: 2.0994e-04
# Epoch 51/100
# 43/43 [==============================] - 4s 101ms/step - loss: 1.8780e-04
# Epoch 52/100
# 43/43 [==============================] - 4s 98ms/step - loss: 1.9982e-04
# Epoch 53/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.8452e-04
# Epoch 54/100
# 43/43 [==============================] - 4s 98ms/step - loss: 1.8003e-04
# Epoch 55/100
# 43/43 [==============================] - 4s 99ms/step - loss: 2.0354e-04
# Epoch 56/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.8588e-04
# Epoch 57/100
# 43/43 [==============================] - 4s 101ms/step - loss: 1.7340e-04
# Epoch 58/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.7664e-04
# Epoch 59/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.7583e-04
# Epoch 60/100
# 43/43 [==============================] - 4s 101ms/step - loss: 1.6938e-04
# Epoch 61/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.8919e-04
# Epoch 62/100
# 43/43 [==============================] - 4s 98ms/step - loss: 1.7319e-04
# Epoch 63/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.6859e-04
# Epoch 64/100
# 43/43 [==============================] - 4s 104ms/step - loss: 1.7187e-04
# Epoch 65/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.6288e-04
# Epoch 66/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.5986e-04
# Epoch 67/100
# 43/43 [==============================] - 4s 101ms/step - loss: 2.0416e-04
# Epoch 68/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.6905e-04
# Epoch 69/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.9759e-04
# Epoch 70/100
# 43/43 [==============================] - 4s 98ms/step - loss: 1.8891e-04
# Epoch 71/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.5741e-04
# Epoch 72/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.6016e-04
# Epoch 73/100
# 43/43 [==============================] - 4s 97ms/step - loss: 1.6853e-04
# Epoch 74/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.6677e-04
# Epoch 75/100
# 43/43 [==============================] - 4s 104ms/step - loss: 1.7365e-04
# Epoch 76/100
# 43/43 [==============================] - 5s 107ms/step - loss: 1.7473e-04
# Epoch 77/100
# 43/43 [==============================] - 4s 104ms/step - loss: 1.7325e-04
# Epoch 78/100
# 43/43 [==============================] - 5s 110ms/step - loss: 1.5891e-04
# Epoch 79/100
# 43/43 [==============================] - 5s 106ms/step - loss: 1.7287e-04
# Epoch 80/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.5761e-04
# Epoch 81/100
# 43/43 [==============================] - 4s 101ms/step - loss: 1.6644e-04
# Epoch 82/100
# 43/43 [==============================] - 4s 101ms/step - loss: 1.6864e-04
# Epoch 83/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.7066e-04
# Epoch 84/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.6988e-04
# Epoch 85/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.6160e-04
# Epoch 86/100
# 43/43 [==============================] - 4s 103ms/step - loss: 1.7970e-04
# Epoch 87/100
# 43/43 [==============================] - 5s 105ms/step - loss: 1.5993e-04
# Epoch 88/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.7226e-04
# Epoch 89/100
# 43/43 [==============================] - 4s 103ms/step - loss: 1.6721e-04
# Epoch 90/100
# 43/43 [==============================] - 4s 103ms/step - loss: 1.7530e-04
# Epoch 91/100
# 43/43 [==============================] - 4s 103ms/step - loss: 1.6077e-04
# Epoch 92/100
# 43/43 [==============================] - 4s 101ms/step - loss: 1.6322e-04
# Epoch 93/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.6220e-04
# Epoch 94/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.7364e-04
# Epoch 95/100
# 43/43 [==============================] - 4s 102ms/step - loss: 1.6436e-04
# Epoch 96/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.6162e-04
# Epoch 97/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.6784e-04
# Epoch 98/100
# 43/43 [==============================] - 4s 99ms/step - loss: 1.6226e-04
# Epoch 99/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.8008e-04
# Epoch 100/100
# 43/43 [==============================] - 4s 100ms/step - loss: 1.6536e-04

# %%
# creating test data
test_data = scaled_data[cutoff-100:,:]
X_test = []
y_test = dataset[cutoff:,:]

for i in range(100,len(test_data)):
    X_test.append(test_data[i-100:i, 0])

# %%
# convert X_test to numpy array
X_test = np.array(X_test)

# %%
# reshape X_test for LSTM model
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# get model preds
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
# get rmse
lstm_rmse = mean_squared_error(y_test,predictions,squared=False)
lstm_rmse
# Out:
# 0.6912134627204154

# %%
# plot the data
train = data[:cutoff]
actual = data[cutoff:]

actual['Predictions'] = predictions

# %%
# visualize 
plt.figure(figsize=(16,8))
plt.title("Model Forecast For SWPPX")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.plot(train['close'])
plt.plot(actual['close'])
plt.plot(actual['Predictions'])
plt.legend(['Train','Actual','Predictions'],loc='lower right')
plt.show()

# %% [markdown]
# ### FBprophet Model

# %%
# Fbprophet Helper functions

# formats dataframe to meet fbprophet requirements
def prep_dataframe(df):
    ts = df.copy()
    ts.rename(columns={'close':'y'},inplace=True)
    ts.index.name = 'ds'
    ts = ts.reset_index()
    ts['ds'] = ts['ds'].apply(lambda x: x.replace(tzinfo=None))
    return ts

# creates training and test set and fit the prophet model
def fit_train(data,prepared=True):
    # Format dataframe to fbprophet requirements in not already done
    if prepared == False:
        data = prep_dataframe(data)

    # Train-Test Split
    cutoff = int(data.shape[0] * 0.80)
    train = data.iloc[:cutoff]
    test = data.iloc[cutoff:]

    # Fit the model
    mod = Prophet(interval_width=0.95,weekly_seasonality=True,daily_seasonality=True)
    fitted_mod = mod.fit(train)

    if prepared == False:
        return fitted_mod, data, train, test
    else:
        return fitted_mod, train, test

# creates predictions using fitted model
def get_preds(model,test_data):
    preds = model.predict(test_data[['ds']])
    return preds[['ds','yhat_lower','yhat_upper','yhat']]

def get_rmse(preds, test_data):
    return mean_squared_error(preds['yhat'],test_data['y'],squared=False)

# %%
mod, SWPPX_prepped, train, test = fit_train(SWPPX,False)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
predictions = get_preds(mod,test)

# %%
fbprophet_rmse = get_rmse(predictions,test)

# %%
fbprophet_rmse
# Out:
# 5.617840243660562

# %%
train = train.set_index('ds')
test = test.set_index('ds')

# %%
predictions = predictions[['ds','yhat']].set_index('ds')

# %%
plt.figure(figsize=(15,5))
plt.title('FBprophet Forecast For SWPPX')
plt.xlabel('Date')
plt.ylabel("Close Price in USD ($)")
plt.plot(train['y'],label="train")
plt.plot(test['y'],c='green',label='actual')
plt.plot(predictions['yhat'],c='red',label='predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation of Models
#
# Judging the models base on the rmse, we can say thet the LSTM model was the best performing model which yields the lowest RMSE. This means that the LSTM model will give us the most reliable predictions.
#
# Our RMSE for the LSTM model tells us that we can expect our close price predictions to be off, on average, by $0.69.

# %%
rmses = pd.Series( [baseline_rmse, arima_rmse, lstm_rmse, fbprophet_rmse], index=['Baseline','ARIMA','LSTM','FBprophet'])
rmses = pd.DataFrame(rmses,columns=['SWPPX_RMSEs'])
rmses = rmses.reset_index()
rmses.columns = ['Model','SWPPX_RMSEs']
rmses
# Out:
#        Model  SWPPX_RMSEs
# 0   Baseline     3.267562
# 1      ARIMA     5.890846
# 2       LSTM     0.691213
# 3  FBprophet     5.617840

# %% [markdown]
# The next lines are code used to create the model_rmses.csv file that will be used in the Evaluation notebook. No need to rerun the next lines.

# %%
# from google.colab import drive
# drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# rmses_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')
# rmses_df = rmses_df.drop('Unnamed: 0',axis=1)
# rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  VFIAX_RMSEs  VTSAX_RMSEs  QQQ_RMSEs
# 0   Baseline     1.588590  21.442564    19.797750     5.585475  17.215619
# 1      ARIMA     2.292706  36.026600    33.119191     7.658805  22.830807
# 2       LSTM     0.432891   4.124593     4.080433     1.077314   5.309794
# 3  FBprophet     5.670109  32.488233    31.884724    10.883668  63.844688

# %%
# rmses_df = pd.concat([rmses_df,rmses[['SWPPX_RMSEs']]],axis=1)
# rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  VTSAX_RMSEs  QQQ_RMSEs  SWPPX_RMSEs
# 0   Baseline     1.588590  21.442564  ...     5.585475  17.215619     3.267562
# 1      ARIMA     2.292706  36.026600  ...     7.658805  22.830807     5.890846
# 2       LSTM     0.432891   4.124593  ...     1.077314   5.309794     0.691213
# 3  FBprophet     5.670109  32.488233  ...    10.883668  63.844688     5.617840
#
# [4 rows x 7 columns]

# %%
# rmses_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')

# %% [markdown]
# ### Forecasting Future Closing Prices
#
# Now that we have found our best working model, we will use it to find the close prices for the next 365 days and use them to calculate the ROI from the current day to the last forecasted day.

# %%
# next 365 days close price predictions
future_predictions = []

last_100_days = X_test[-1] # real

while len(future_predictions) != 365:
    # reshape the input array for the lstm model
    X = np.reshape(last_100_days, (last_100_days.shape[1], last_100_days.shape[0], 1))
    # make one new prediction
    forecast = model.predict(X) 
    # update last_100_days dropping first value and adding the new prediction to the end of the array
    new = np.concatenate((last_100_days, forecast))
    last_100_days = new[1:]
    # append unscaled prediction to future predictions
    future_predictions.append(scaler.inverse_transform(forecast)[0])

# %%
predictions_df = pd.DataFrame(future_predictions,columns=['close'])
SWPPX_copy = SWPPX.copy()
SWPPX_copy = SWPPX.reset_index()
SWPPX_copy['date'] = SWPPX_copy['date'].apply(lambda x: x.replace(tzinfo=None))
SWPPX_copy
# Out:
#            date  close
# 0    2017-01-12  34.93
# 1    2017-01-13  35.00
# 2    2017-01-14  34.89
# 3    2017-01-15  34.89
# 4    2017-01-16  34.89
# ...         ...    ...
# 1820 2022-01-06  71.89
# 1821 2022-01-07  71.61
# 1822 2022-01-08  71.51
# 1823 2022-01-09  71.51
# 1824 2022-01-10  71.51
#
# [1825 rows x 2 columns]

# %%
# getting dates for the next 365 days

from datetime import datetime, timedelta

def date_range(start, end):
    delta = end - start  # as timedelta
    days = [start + timedelta(days=i) for i in range(delta.days + 1)]
    return days

# last date from the data
start_date = SWPPX_copy.iloc[-1,0]

end_date = datetime(2023, 1, 10)
    
future_dates = date_range(start_date, end_date)[1:]

# %%
# Create new dataframe with next 365 day close price predictions 
predictions_df['date'] = future_dates
predictions_df = predictions_df[['date','close']]
SWPPX_copy_2 = pd.concat([SWPPX_copy,predictions_df])
# Final dataframe with old data and next 365 day predictions
SWPPX_copy_2 = SWPPX_copy_2.set_index('date')

# %%
# Find the ROI for the next 365 days
ROI_next_365_days = (SWPPX_copy_2.iloc[-1] - SWPPX_copy_2.iloc[-366]) / SWPPX_copy_2.iloc[-366]
print(f"Next 365 days ROI: {round(ROI_next_365_days[0]*100,2)}%")
# Out:
# Next 365 days ROI: 36.85%

# %% [markdown]
# The next lines of code were used to create the rois.csv file that will be used in the evaluation notebook. No need to rerun the next lines.

# %%
# roi_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
# roi_df
# Out:
#    Unnamed: 0  NASDX_ROI  IVV_ROI  VFIAX_ROI  VTSAX_ROI   QQQ_ROI
# 0           0   0.267214  0.33298   0.400738   0.421071  0.318488

# %%
# roi_df = roi_df.drop('Unnamed: 0',axis=1)
# roi_df['SWPPX_ROI'] = ROI_next_365_days.values

# %%
# roi_df
# Out:
#    NASDX_ROI  IVV_ROI  VFIAX_ROI  VTSAX_ROI   QQQ_ROI  SWPPX_ROI
# 0   0.267214  0.33298   0.400738   0.421071  0.318488   0.368498

# %%
# roi_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
