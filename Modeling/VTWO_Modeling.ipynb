# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
# important to set a keras random seed for reproducibility on the LSTM model
tf.keras.utils.set_random_seed(42)

from keras.models import Sequential
from keras.layers import Dense, LSTM

# Change to statsmodels.tsa.arima.model on jupyter notebook.
# statsmodels.tsa.arima_model for google colab
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from fbprophet import Prophet

import warnings
warnings.simplefilter('ignore')

plt.style.use("fivethirtyeight")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# for working on google colab 
# skip cell if working on jupyter notebook
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec7b5632-43b2-4f8c-8d58-85964f320f26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec7b5632-43b2-4f8c-8d58-85964f320f26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index_funds_data.csv to index_funds_data.csv

# %% [markdown]
# We begin by importing our funds csv and selecting the data for the ticker name of interest. The price that we will be focusing on will be the Close price of the fund, therefore we will only concern ourselves with the close column. We will also take the opportunity convert the date column into a datetime object.

# %%
# change path to '../data/index_funds_data.csv' if working on jupyter notebook

funds = pd.read_csv('index_funds_data.csv')
funds['date'] = pd.to_datetime(funds['date'],infer_datetime_format=True)
funds = funds[['symbol','date','close']]
funds = funds.set_index(['symbol','date'])
VTWO = funds.loc['VTWO',['close']]

# %% [markdown]
# ### Visualize The Closing Price
#
# Below we plot the time series for the fund to get an initial look at what the series looks like.

# %%
plt.figure(figsize=(16,8))
plt.plot(VTWO['close'])
plt.title("Close Price History")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.show()

# %% [markdown]
# ### Baseline "Naive" Model

# %% [markdown]
# To set up a baseline model, we shift the time series by 100 days forward. This is known a naive forecast. By shifting the time series, we are using the shifted series to represent our predictions of the closing price.

# %%
VTWO_baseline = VTWO.shift(100)
VTWO_base_rmse = mean_squared_error(VTWO[100:],VTWO_baseline[100:],squared=False)
VTWO_base_rmse
# Out:
# 26.47846759191806

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.set_title("Baseline Forecast")
ax.plot(VTWO,c='b',label='Actual')
ax.plot(VTWO_baseline,c='r',label='Baseline')
plt.legend()
plt.show()

# %% [markdown]
# To test the performance of our baseline we decide on a cutoff to split our original time series into the train set and test set. We also split the time series of our baseline using the same cutoff to create a the train predictions and test predictions. Next we calculate the RMSE of the baseline using the test predictions and the actual values, which is the test set from the original time series.

# %%
new_df = pd.DataFrame()
new_df['original'] = VTWO['close']
new_df['shifted'] = VTWO['close'].shift(100)
cutoff = int(len(new_df['original']) * 0.80)
original = new_df['original']
shifted = new_df['shifted']
original_train, original_test = original[100:cutoff], original[cutoff:]
shifted_train, shifted_test = shifted[100:cutoff], shifted[cutoff:]

# %%
baseline_rmse = mean_squared_error(original_train,shifted_train,squared=False)
baseline_rmse
# Out:
# 15.034654365073887

# %% [markdown]
# To help visualize the results from the baseline, we plot each set below.

# %%
plt.figure(figsize=(10,4))
plt.title('VTWO Baseline Forecast')
plt.plot(original_train,label='Train')
plt.plot(original_test,c='r',label='Actual')
plt.plot(shifted_test,c='blue',label='Baseline Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA Modeling
# Next, we move on to the next modeling techinique. We have defined various helper functions below to help us with the ARIMA modeling process.
#
# As we recall from the EDA notebook, the time series is not stationary to begin with. By applying differencing, we were able to convert the time series into a stationary one. This means we can expect to have an ARIMA model with at least a first order differencing.

# %%
# Arima Helper Functions

# get all possible combinations of (p,d,q) for a range (n,k)
def get_combos(n,k):
    p = d = q = range(n, k)
    pdq = list(itertools.product(p, d, q))
    pdqs = [(x[0], x[1], x[2]) for x in list(itertools.product(p, d, q))]
    return pdqs

# find the optimal order for arima model for a series
def get_optimal_params(ts,n,k):
    pdq = get_combos(n,k)
    ans = []
    for comb in pdq:
        try:
            model = ARIMA(ts,
                         order=comb)
            output = model.fit()
            ans.append([comb,output.aic])
        except:
            continue
    ans_df = pd.DataFrame(ans, columns=['pdq','aic'])
    optimals = ans_df.loc[ans_df['aic'].idxmin()]
    return optimals

# fit arima model
def arima_models(ts,n,k):
    order = get_optimal_params(ts,n,k)['pdq']
    model = ARIMA(ts,
                 order=order)
    output = model.fit()
    return output

# time series train test split
def train_test_splt(ts,test_size):
    cutoff = int(ts.shape[0]*(1-test_size))
    train = ts[:cutoff]
    test = ts[cutoff:]
    return train, test

def find_rmse(model, test_data):
    y_hat = model.predict(start=test_data.index[0], end=test_data.index[-1], typ='levels')
    return y_hat, np.sqrt(mean_squared_error(test_data, y_hat))

# %%
VTWO_train, VTWO_test = train_test_splt(VTWO,.2)

# Find optimal pdq
print(get_optimal_params(VTWO_train,0,3))

# Fit ARIMA with optimal pdq
arima_model = arima_models(VTWO_train,0,3)

# Summary of model
arima_model.summary()
# Out:
# pdq    (2, 1, 0)
# aic       5171.7
# Name: 18, dtype: object
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                 1459
# Model:                 ARIMA(2, 1, 0)   Log Likelihood               -2581.852
# Method:                       css-mle   S.D. of innovations              1.420
# Date:                Wed, 26 Jan 2022   AIC                           5171.705
# Time:                        09:51:41   BIC                           5192.847
# Sample:                    01-13-2017   HQIC                          5179.592
#                          - 01-10-2021
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0404      0.038      1.066      0.286      -0.034       0.115
# ar.L1.D.close    -0.0425      0.026     -1.625      0.104      -0.094       0.009
# ar.L2.D.close     0.0601      0.026      2.300      0.022       0.009       0.111
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.7414           +0.0000j            3.7414            0.5000
# AR.2            4.4480           +0.0000j            4.4480            0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# Looking at the ARIMA summary table, we can see that the model did in fact apply differencing to our model. Our p-values on our coefficients are low enough, which tell us that they are significant. After an iterative search for the best parameter, this is the best fitting ARIMA model with the lowest AIC score.

# %% [markdown]
# Next we will calculate the RMSE for this model to evaluate it's performance.

# %%
yhat ,arima_rmse = find_rmse(arima_model,VTWO_test)

# %%
arima_rmse
# Out:
# 73.85063550985237

# %% [markdown]
# Now we can plot the forecast to visually see how off or close our predictions are to the test data.

# %%
plt.figure(figsize=(15,4))
plt.title('ARIMA model VTWO Forecast')
plt.xlabel('Date')
plt.ylabel('Close Price in USD ($)')
plt.plot(VTWO_train,c="blue",label='Train')
plt.plot(VTWO_test,c='green',label='Actual')
plt.plot(yhat, c='red',label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# Our next modeling technique will be the LSTM model. This is a special type of RNN that are especially useful for time series data.

# %%
data = VTWO.filter(['close'])
dataset = data.values
cutoff = int(len(dataset)*0.8)
cutoff
# Out:
# 1460

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.25928637],
#        [0.26724611],
#        [0.25251601],
#        ...,
#        [0.06184812],
#        [0.06184812],
#        [0.06184812]])

# %%
# create scaled training set
train_data = scaled_data[0:cutoff,:]
X_train = []
y_train = []

for i in range(100,len(train_data)):
    X_train.append(train_data[i-100:i,0])
    y_train.append(train_data[i,0])

# %%
# convert X_train and y_train to numpy arrays for training the model
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# reshape X_train for LSTM model
print(X_train.shape)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (1360, 100)
# (1360, 100, 1)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model
model.fit(X_train, y_train, batch_size=16,epochs=100)
# Out:
# Epoch 1/100
# 85/85 [==============================] - 11s 88ms/step - loss: 0.0056
# Epoch 2/100
# 85/85 [==============================] - 6s 72ms/step - loss: 9.7560e-04
# Epoch 3/100
# 85/85 [==============================] - 6s 65ms/step - loss: 8.7840e-04
# Epoch 4/100
# 85/85 [==============================] - 6s 65ms/step - loss: 8.0739e-04
# Epoch 5/100
# 85/85 [==============================] - 6s 66ms/step - loss: 6.9745e-04
# Epoch 6/100
# 85/85 [==============================] - 6s 65ms/step - loss: 5.8320e-04
# Epoch 7/100
# 85/85 [==============================] - 6s 65ms/step - loss: 5.6396e-04
# Epoch 8/100
# 85/85 [==============================] - 6s 65ms/step - loss: 4.9825e-04
# Epoch 9/100
# 85/85 [==============================] - 6s 65ms/step - loss: 5.2667e-04
# Epoch 10/100
# 85/85 [==============================] - 6s 65ms/step - loss: 5.0769e-04
# Epoch 11/100
# 85/85 [==============================] - 6s 74ms/step - loss: 4.4545e-04
# Epoch 12/100
# 85/85 [==============================] - 6s 65ms/step - loss: 4.8902e-04
# Epoch 13/100
# 85/85 [==============================] - 6s 74ms/step - loss: 4.4928e-04
# Epoch 14/100
# 85/85 [==============================] - 6s 65ms/step - loss: 5.4033e-04
# Epoch 15/100
# 85/85 [==============================] - 6s 66ms/step - loss: 4.0359e-04
# Epoch 16/100
# 85/85 [==============================] - 6s 65ms/step - loss: 3.9833e-04
# Epoch 17/100
# 85/85 [==============================] - 5s 65ms/step - loss: 3.7900e-04
# Epoch 18/100
# 85/85 [==============================] - 7s 83ms/step - loss: 3.4811e-04
# Epoch 19/100
# 85/85 [==============================] - 7s 83ms/step - loss: 3.2885e-04
# Epoch 20/100
# 85/85 [==============================] - 6s 66ms/step - loss: 3.1396e-04
# Epoch 21/100
# 85/85 [==============================] - 6s 66ms/step - loss: 3.2447e-04
# Epoch 22/100
# 85/85 [==============================] - 5s 64ms/step - loss: 3.0985e-04
# Epoch 23/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.7552e-04
# Epoch 24/100
# 85/85 [==============================] - 6s 65ms/step - loss: 3.1009e-04
# Epoch 25/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.5210e-04
# Epoch 26/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.5544e-04
# Epoch 27/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.5875e-04
# Epoch 28/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.9131e-04
# Epoch 29/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.3869e-04
# Epoch 30/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.1668e-04
# Epoch 31/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.7377e-04
# Epoch 32/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.1712e-04
# Epoch 33/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.4674e-04
# Epoch 34/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.3615e-04
# Epoch 35/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0317e-04
# Epoch 36/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.1331e-04
# Epoch 37/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.0576e-04
# Epoch 38/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.2347e-04
# Epoch 39/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0611e-04
# Epoch 40/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9449e-04
# Epoch 41/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9196e-04
# Epoch 42/100
# 85/85 [==============================] - 6s 65ms/step - loss: 1.9295e-04
# Epoch 43/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.1374e-04
# Epoch 44/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.1510e-04
# Epoch 45/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.0716e-04
# Epoch 46/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.1263e-04
# Epoch 47/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0650e-04
# Epoch 48/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9786e-04
# Epoch 49/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0818e-04
# Epoch 50/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.2629e-04
# Epoch 51/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.3247e-04
# Epoch 52/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.2905e-04
# Epoch 53/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.2515e-04
# Epoch 54/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9933e-04
# Epoch 55/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.3097e-04
# Epoch 56/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9231e-04
# Epoch 57/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9889e-04
# Epoch 58/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9915e-04
# Epoch 59/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.0342e-04
# Epoch 60/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.1004e-04
# Epoch 61/100
# 85/85 [==============================] - 6s 68ms/step - loss: 2.0716e-04
# Epoch 62/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.0167e-04
# Epoch 63/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.7410e-04
# Epoch 64/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.1119e-04
# Epoch 65/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.0070e-04
# Epoch 66/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0626e-04
# Epoch 67/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.8729e-04
# Epoch 68/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.1028e-04
# Epoch 69/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0404e-04
# Epoch 70/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9243e-04
# Epoch 71/100
# 85/85 [==============================] - 6s 65ms/step - loss: 1.9297e-04
# Epoch 72/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9457e-04
# Epoch 73/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.0732e-04
# Epoch 74/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0622e-04
# Epoch 75/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.0222e-04
# Epoch 76/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.1864e-04
# Epoch 77/100
# 85/85 [==============================] - 6s 65ms/step - loss: 1.9335e-04
# Epoch 78/100
# 85/85 [==============================] - 6s 65ms/step - loss: 1.8749e-04
# Epoch 79/100
# 85/85 [==============================] - 6s 65ms/step - loss: 1.9303e-04
# Epoch 80/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.5225e-04
# Epoch 81/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.2485e-04
# Epoch 82/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9717e-04
# Epoch 83/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.1004e-04
# Epoch 84/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9095e-04
# Epoch 85/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9899e-04
# Epoch 86/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.0954e-04
# Epoch 87/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.8849e-04
# Epoch 88/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9294e-04
# Epoch 89/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.0667e-04
# Epoch 90/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.0036e-04
# Epoch 91/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.0221e-04
# Epoch 92/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.8749e-04
# Epoch 93/100
# 85/85 [==============================] - 6s 67ms/step - loss: 1.9766e-04
# Epoch 94/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.9897e-04
# Epoch 95/100
# 85/85 [==============================] - 6s 67ms/step - loss: 2.0247e-04
# Epoch 96/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.0704e-04
# Epoch 97/100
# 85/85 [==============================] - 6s 66ms/step - loss: 2.2423e-04
# Epoch 98/100
# 85/85 [==============================] - 6s 66ms/step - loss: 1.8710e-04
# Epoch 99/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.1368e-04
# Epoch 100/100
# 85/85 [==============================] - 6s 65ms/step - loss: 2.2104e-04

# %%
# creating test data
test_data = scaled_data[cutoff-100:,:]
X_test = []
y_test = dataset[cutoff:,:]

for i in range(100,len(test_data)):
    X_test.append(test_data[i-100:i, 0])

# %%
# convert X_test to numpy array
X_test = np.array(X_test)

# %%
# reshape X_test for LSTM model
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# get model preds
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
# get rmse
lstm_rmse = mean_squared_error(y_test,predictions,squared=False)
lstm_rmse
# Out:
# 5.2970215504892675

# %%
# plot the data
train = data[:cutoff]
actual = data[cutoff:]

actual['Predictions'] = predictions

# %%
# visualize 
plt.figure(figsize=(16,8))
plt.title("Model Forecast For VTWO")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.plot(train['close'])
plt.plot(actual['close'])
plt.plot(actual['Predictions'])
plt.legend(['Train','Actual','Predictions'],loc='lower right')
plt.show()

# %% [markdown]
# ### FBprophet Model

# %%
# Fbprophet Helper functions

# formats dataframe to meet fbprophet requirements
def prep_dataframe(df):
    ts = df.copy()
    ts.rename(columns={'close':'y'},inplace=True)
    ts.index.name = 'ds'
    ts = ts.reset_index()
    ts['ds'] = ts['ds'].apply(lambda x: x.replace(tzinfo=None))
    return ts

# creates training and test set and fit the prophet model
def fit_train(data,prepared=True):
    # Format dataframe to fbprophet requirements in not already done
    if prepared == False:
        data = prep_dataframe(data)

    # Train-Test Split
    cutoff = int(data.shape[0] * 0.80)
    train = data.iloc[:cutoff]
    test = data.iloc[cutoff:]

    # Fit the model
    mod = Prophet(interval_width=0.95,weekly_seasonality=True,daily_seasonality=True)
    fitted_mod = mod.fit(train)

    if prepared == False:
        return fitted_mod, data, train, test
    else:
        return fitted_mod, train, test

# creates predictions using fitted model
def get_preds(model,test_data):
    preds = model.predict(test_data[['ds']])
    return preds[['ds','yhat_lower','yhat_upper','yhat']]

def get_rmse(preds, test_data):
    return mean_squared_error(preds['yhat'],test_data['y'],squared=False)

# %%
mod, VTWO_prepped, train, test = fit_train(VTWO,False)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
predictions = get_preds(mod,test)

# %%
fbprophet_rmse = get_rmse(predictions,test)

# %%
fbprophet_rmse
# Out:
# 102.42885398473558

# %%
train = train.set_index('ds')
test = test.set_index('ds')

# %%
predictions = predictions[['ds','yhat']].set_index('ds')

# %%
plt.figure(figsize=(15,5))
plt.title('FBprophet Forecast For VTWO')
plt.xlabel('Date')
plt.ylabel("Close Price in USD ($)")
plt.plot(train['y'],label="train")
plt.plot(test['y'],c='green',label='actual')
plt.plot(predictions['yhat'],c='red',label='predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation of Models
#
# Judging the models based on the RMSE, we can say that the LSTM model was the best performing model since it yields the lowest RMSE. This means that the LSTM model will give us the most reliable predictions.
#
# Our RMSE for the LSTM model tells us that we can expect our close price predictions to be off, on average, by $5.30.

# %%
rmses = pd.Series( [baseline_rmse, arima_rmse, lstm_rmse, fbprophet_rmse], index=['Baseline','ARIMA','LSTM','FBprophet'])
rmses = pd.DataFrame(rmses,columns=['VTWO_RMSEs'])
rmses = rmses.reset_index()
rmses.columns = ['Model','VTWO_RMSEs']
rmses
# Out:
#        Model  VTWO_RMSEs
# 0   Baseline   15.034654
# 1      ARIMA   73.850636
# 2       LSTM    5.297022
# 3  FBprophet  102.428854

# %% [markdown]
# The next lines are used to create the model_rmses.csv file that will be used in the Evaluation Notebook. No need to rerun the next lines.

# %%
# from google.colab import drive
# drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# rmses_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')
# rmses_df = rmses_df.drop('Unnamed: 0',axis=1)
# rmses_df = pd.concat([rmses_df,rmses[['VTWO_RMSEs']]],axis=1)
# rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  SPY_RMSEs  VOO_RMSEs  VTWO_RMSEs
# 0   Baseline     2.047809  25.747396  ...  25.613167  23.600016   15.034654
# 1      ARIMA     2.292706  36.026600  ...  35.735622  32.937877   73.850636
# 2       LSTM     0.432891   4.124593  ...   4.413672   3.852907    5.297022
# 3  FBprophet     5.670109  32.488233  ...  35.484111  31.302444  102.428854
#
# [4 rows x 14 columns]

# %%
# rmses_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')

# %% [markdown]
# ### Forecasting Future Closing Prices
#
# Now that we have found our best working model, we will use it to find the close prices for the rest of 2022 to and calculate the ROI from the current day to the last forecasted day.

# %%
X_test[-1].shape
# Out:
# (100, 1)

# %%
# daily close price predictions for the next year
future_predictions = []

last_100_days = X_test[-1] # real

while len(future_predictions) != 365:
    # reshape the input array for the lstm model
    X = np.reshape(last_100_days, (last_100_days.shape[1], last_100_days.shape[0], 1))
    # make one new prediction
    forecast = model.predict(X) 
    # update last_100_days dropping first value and adding the new prediction to the end of the array
    new = np.concatenate((last_100_days, forecast))
    last_100_days = new[1:]
    # append unscaled prediction to future predictions
    future_predictions.append(scaler.inverse_transform(forecast)[0])

# %%
len(future_predictions)
# Out:
# 365

# %%
predictions_df = pd.DataFrame(future_predictions,columns=['close'])
VTWO_copy = VTWO.copy()
VTWO_copy = VTWO.reset_index()
VTWO_copy['date'] = VTWO_copy['date'].apply(lambda x: x.replace(tzinfo=None))
VTWO_copy
# Out:
#            date   close
# 0    2017-01-12  108.40
# 1    2017-01-13  109.27
# 2    2017-01-14  107.66
# 3    2017-01-15  107.66
# 4    2017-01-16  107.66
# ...         ...     ...
# 1820 2022-01-06   88.11
# 1821 2022-01-07   87.09
# 1822 2022-01-08   86.82
# 1823 2022-01-09   86.82
# 1824 2022-01-10   86.82
#
# [1825 rows x 2 columns]

# %%
# getting dates for the next 60 days

from datetime import datetime, timedelta

def date_range(start, end):
    delta = end - start  # as timedelta
    days = [start + timedelta(days=i) for i in range(delta.days + 1)]
    return days

# last date from the data
start_date = VTWO_copy.iloc[-1,0]

end_date = datetime(2023, 1, 10)
    
future_dates = date_range(start_date, end_date)[1:]
len(future_dates)
# Out:
# 365

# %%
# Create new dataframe with next 365 day close price predictions 
predictions_df['date'] = future_dates
predictions_df = predictions_df[['date','close']]
VTWO_copy_2 = pd.concat([VTWO_copy,predictions_df])
# Final dataframe with old data and next 365 day predictions
VTWO_copy_2 = VTWO_copy_2.set_index('date')

# %%
VTWO_copy_2.head()
# Out:
#              close
# date
# 2017-01-12  108.40
# 2017-01-13  109.27
# 2017-01-14  107.66
# 2017-01-15  107.66
# 2017-01-16  107.66

# %%
VTWO_copy_2.iloc[-366]
# Out:
# close    86.82
# Name: 2022-01-10 00:00:00, dtype: float64

# %%
# Find the ROI for the next 365 days
ROI_next_365_days = (VTWO_copy_2.iloc[-1] - VTWO_copy_2.iloc[-366]) / VTWO_copy_2.iloc[-366]
ROI_df = pd.DataFrame(ROI_next_365_days, columns=['VTWO_ROI'])
print(f"Next 365 days ROI: {round(ROI_next_365_days[0]*100,2)}%")
# Out:
# Next 365 days ROI: 95.32%

# %% [markdown]
# The next lines are used to create the rois.csv file that will be used in the Evaluation Notebook. No need to rerun the next lines.

# %%
# roi_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
# roi_df = roi_df.drop('Unnamed: 0',axis=1)
# roi_df['VTWO_ROI'] = ROI_next_365_days.values
# roi_df
# Out:
#    NASDX_ROI  IVV_ROI  VFIAX_ROI  ...   SPY_ROI   VOO_ROI  VTWO_ROI
# 0   0.267214  0.33298   0.400738  ...  0.424128  0.356532  0.953169
#
# [1 rows x 13 columns]

# %%
# roi_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
