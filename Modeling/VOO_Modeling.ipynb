# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
# important to set a keras random seed for reproducibility on the LSTM model
tf.keras.utils.set_random_seed(42)

from keras.models import Sequential
from keras.layers import Dense, LSTM

# Change to statsmodels.tsa.arima.model on jupyter notebook.
# statsmodels.tsa.arima_model for google colab
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from fbprophet import Prophet

import warnings
warnings.simplefilter('ignore')

plt.style.use("fivethirtyeight")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# for working on google colab 
# skip cell if working on jupyter notebook
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58026a01-b2ca-4fe5-8ec7-a9386c0fa54f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58026a01-b2ca-4fe5-8ec7-a9386c0fa54f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index_funds_data.csv to index_funds_data.csv

# %% [markdown]
# We begin by importing our funds csv and selecting the data for the ticker name of interest. The price that we will be focusing on will be the Close price of the fund, therefore we will only concern ourselves with the close column. We will also take the opportunity convert the date column into a datetime object.

# %%
funds = pd.read_csv('index_funds_data.csv')
funds['date'] = pd.to_datetime(funds['date'],infer_datetime_format=True)
funds = funds[['symbol','date','close']]
funds = funds.set_index(['symbol','date'])
VOO = funds.loc['VOO',['close']]

# %% [markdown]
# ### Visualize The Closing Price
#
# Below we plot the time series for the fund to get an initial look at what the series looks like.

# %%
plt.figure(figsize=(16,8))
plt.plot(VOO['close'])
plt.title("Close Price History")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.show()

# %% [markdown]
# ### Baseline "Naive" Model

# %% [markdown]
# To set up a baseline model, we shift the time series by 60 days forward. This is known a naive forecast.

# %%
VOO_baseline = VOO.shift(60)
VOO_base_rmse = mean_squared_error(VOO[60:],VOO_baseline[60:],squared=False)
VOO_base_rmse
# Out:
# 19.25258484898997

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.set_title("Baseline Forecast")
ax.plot(VOO,c='b',label='Actual')
ax.plot(VOO_baseline,c='r',label='Baseline')
plt.legend()
plt.show()

# %% [markdown]
# To test the performance of our baseline we decide on a cutoff to split our original time series into the train set and test set. We also split the time series of our baseline using the same cutoff to create a the train predictions and test predictions. Next we calculate the RMSE of the baseline using the test predictions and the actual values, which is the test set from the original time series.

# %%
new_df = pd.DataFrame()
new_df['original'] = VOO['close']
new_df['shifted'] = VOO['close'].shift(60)
cutoff = int(len(new_df['original']) * 0.80)
original = new_df['original']
shifted = new_df['shifted']
original_train, original_test = original[60:cutoff], original[cutoff:]
shifted_train, shifted_test = shifted[60:cutoff], shifted[cutoff:]

# %%
baseline_rmse = mean_squared_error(original_train,shifted_train,squared=False)
baseline_rmse
# Out:
# 19.66119545020706

# %% [markdown]
# To help visualize the results from the baseline, we plot each set below.

# %%
plt.figure(figsize=(10,4))
plt.title('VOO Baseline Forecast')
plt.plot(original_train,label='Train')
plt.plot(original_test,c='r',label='Actual')
plt.plot(shifted_test,c='blue',label='Baseline Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA Modeling
# Next, we move on to the next modeling techinique. We have defined various helper functions below to help us with the ARIMA modeling process.
#
# As we recall from the EDA notebook, the time series is not stationary to begin with. Applying differencing was able to convert the time series to a stationary one. So we can expect to have an ARIMA model with at least a first order differencing.

# %%
# Arima Helper Functions

# get all possible combinations of (p,d,q) for a range (n,k)
def get_combos(n,k):
    p = d = q = range(n, k)
    pdq = list(itertools.product(p, d, q))
    pdqs = [(x[0], x[1], x[2]) for x in list(itertools.product(p, d, q))]
    return pdqs

# find the optimal order for arima model for a series
def get_optimal_params(ts,n,k):
    pdq = get_combos(n,k)
    ans = []
    for comb in pdq:
        try:
            model = ARIMA(ts,
                         order=comb)
            output = model.fit()
            ans.append([comb,output.aic])
        except:
            continue
    ans_df = pd.DataFrame(ans, columns=['pdq','aic'])
    optimals = ans_df.loc[ans_df['aic'].idxmin()]
    return optimals

# fit arima model
def arima_models(ts,n,k):
    order = get_optimal_params(ts,n,k)['pdq']
    model = ARIMA(ts,
                 order=order)
    output = model.fit()
    return output

# time series train test split
def train_test_splt(ts,test_size):
    cutoff = int(ts.shape[0]*(1-test_size))
    train = ts[:cutoff]
    test = ts[cutoff:]
    return train, test

def find_rmse(model, test_data):
    y_hat = model.predict(start=test_data.index[0], end=test_data.index[-1], typ='levels')
    return y_hat, np.sqrt(mean_squared_error(test_data, y_hat))

# %%
VOO_train, VOO_test = train_test_splt(VOO,.2)

# Find optimal pdq
print(get_optimal_params(VOO_train,0,3))

# Fit ARIMA with optimal pdq
arima_model = arima_models(VOO_train,0,3)

# Summary of model
arima_model.summary()
# Out:
# pdq    (2, 1, 2)
# aic      6978.69
# Name: 22, dtype: object
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                 1459
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -3483.344
# Method:                       css-mle   S.D. of innovations              2.634
# Date:                Mon, 24 Jan 2022   AIC                           6978.687
# Time:                        08:25:32   BIC                           7010.400
# Sample:                    01-13-2017   HQIC                          6990.518
#                          - 01-10-2021
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0960      0.066      1.465      0.143      -0.032       0.224
# ar.L1.D.close    -1.8291      0.022    -81.569      0.000      -1.873      -1.785
# ar.L2.D.close    -0.8949      0.022    -40.719      0.000      -0.938      -0.852
# ma.L1.D.close     1.7468      0.030     57.651      0.000       1.687       1.806
# ma.L2.D.close     0.7911      0.029     27.404      0.000       0.735       0.848
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0219           -0.2703j            1.0571           -0.4588
# AR.2           -1.0219           +0.2703j            1.0571            0.4588
# MA.1           -1.1040           -0.2127j            1.1243           -0.4697
# MA.2           -1.1040           +0.2127j            1.1243            0.4697
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# Looking at the ARIMA summary table, we can see that the model did in fact apply differencing to our model. Our p-values on our coefficients are low enough, which tell us that they are significant. After an iterative search for the best parameter, this is the best fitting ARIMA model with the lowest AIC score.

# %% [markdown]
# Next we will calculate the RMSE for this model to evaluate it's performance.

# %%
yhat ,arima_rmse = find_rmse(arima_model,VOO_test)

# %%
arima_rmse
# Out:
# 32.93787703261937

# %%
plt.figure(figsize=(15,4))
plt.title('ARIMA model VOO Forecast')
plt.xlabel('Date')
plt.ylabel('Close Price in USD ($)')
plt.plot(VOO_train,c="blue",label='Train')
plt.plot(VOO_test,c='green',label='Actual')
plt.plot(yhat, c='red',label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# Our next modeling technique will be the LSTM model. This is a special type of RNN.

# %%
data = VOO.filter(['close'])
dataset = data.values
cutoff = int(len(dataset)*0.8)
cutoff
# Out:
# 1460

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01608648],
#        [0.0178313 ],
#        [0.0146821 ],
#        ...,
#        [0.95225126],
#        [0.95225126],
#        [0.95225126]])

# %%
# create scaled training set
train_data = scaled_data[0:cutoff,:]
X_train = []
y_train = []

for i in range(60,len(train_data)):
    X_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])

# %%
# convert X_train and y_train to numpy arrays for training the model
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# reshape X_train for LSTM model
print(X_train.shape)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (1400, 60)
# (1400, 60, 1)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model
model.fit(X_train, y_train, batch_size=1,epochs=40)
# Out:
# Epoch 1/40
# 1400/1400 [==============================] - 44s 29ms/step - loss: 9.1100e-04
# Epoch 2/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 4.7909e-04
# Epoch 3/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 3.0805e-04
# Epoch 4/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.9642e-04
# Epoch 5/40
# 1400/1400 [==============================] - 41s 30ms/step - loss: 2.7049e-04
# Epoch 6/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 3.1295e-04
# Epoch 7/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.4092e-04
# Epoch 8/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.6835e-04
# Epoch 9/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.5189e-04
# Epoch 10/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.5132e-04
# Epoch 11/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.3257e-04
# Epoch 12/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.3020e-04
# Epoch 13/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.4032e-04
# Epoch 14/40
# 1400/1400 [==============================] - 42s 30ms/step - loss: 2.4537e-04
# Epoch 15/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.2139e-04
# Epoch 16/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.4302e-04
# Epoch 17/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.2007e-04
# Epoch 18/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.2002e-04
# Epoch 19/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.1353e-04
# Epoch 20/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.2415e-04
# Epoch 21/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0332e-04
# Epoch 22/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0082e-04
# Epoch 23/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 1.9745e-04
# Epoch 24/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.1391e-04
# Epoch 25/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0289e-04
# Epoch 26/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.1513e-04
# Epoch 27/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 1.9633e-04
# Epoch 28/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 2.0055e-04
# Epoch 29/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.1215e-04
# Epoch 30/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0050e-04
# Epoch 31/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 1.8977e-04
# Epoch 32/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0599e-04
# Epoch 33/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 1.9491e-04
# Epoch 34/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0112e-04
# Epoch 35/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 1.8598e-04
# Epoch 36/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 1.9628e-04
# Epoch 37/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 2.0009e-04
# Epoch 38/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 1.8872e-04
# Epoch 39/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 1.8853e-04
# Epoch 40/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 1.9456e-04

# %%
# creating test data
test_data = scaled_data[cutoff-60:,:]
X_test = []
y_test = dataset[cutoff:,:]

for i in range(60,len(test_data)):
    X_test.append(test_data[i-60:i, 0])

# %%
# convert X_test to numpy array
X_test = np.array(X_test)

# %%
# reshape X_test for LSTM model
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# get model preds
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
# get rmse
lstm_rmse = mean_squared_error(y_test,predictions,squared=False)
lstm_rmse
# Out:
# 4.440468421853852

# %%
# plot the data
train = data[:cutoff]
actual = data[cutoff:]

actual['Predictions'] = predictions

# %%
# visualize 
plt.figure(figsize=(16,8))
plt.title("Model Forecast For VOO")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.plot(train['close'])
plt.plot(actual['close'])
plt.plot(actual['Predictions'])
plt.legend(['Train','Actual','Predictions'],loc='lower right')
plt.show()

# %% [markdown]
# ### FBprophet Model

# %%
# Fbprophet Helper functions

# formats dataframe to meet fbprophet requirements
def prep_dataframe(df):
    ts = df.copy()
    ts.rename(columns={'close':'y'},inplace=True)
    ts.index.name = 'ds'
    ts = ts.reset_index()
    ts['ds'] = ts['ds'].apply(lambda x: x.replace(tzinfo=None))
    return ts

# creates training and test set and fit the prophet model
def fit_train(data,prepared=True):
    # Format dataframe to fbprophet requirements in not already done
    if prepared == False:
        data = prep_dataframe(data)

    # Train-Test Split
    cutoff = int(data.shape[0] * 0.80)
    train = data.iloc[:cutoff]
    test = data.iloc[cutoff:]

    # Fit the model
    mod = Prophet(interval_width=0.95,weekly_seasonality=True,daily_seasonality=True)
    fitted_mod = mod.fit(train)

    if prepared == False:
        return fitted_mod, data, train, test
    else:
        return fitted_mod, train, test

# creates predictions using fitted model
def get_preds(model,test_data):
    preds = model.predict(test_data[['ds']])
    return preds[['ds','yhat_lower','yhat_upper','yhat']]

def get_rmse(preds, test_data):
    return mean_squared_error(preds['yhat'],test_data['y'],squared=False)

# %%
mod, VOO_prepped, train, test = fit_train(VOO,False)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
predictions = get_preds(mod,test)

# %%
fbprophet_rmse = get_rmse(predictions,test)

# %%
fbprophet_rmse
# Out:
# 31.302444074470646

# %%
train = train.set_index('ds')
test = test.set_index('ds')

# %%
predictions = predictions[['ds','yhat']].set_index('ds')

# %%
plt.figure(figsize=(15,5))
plt.title('FBprophet Forecast For VOO')
plt.xlabel('Date')
plt.ylabel("Close Price in USD ($)")
plt.plot(train['y'],label="train")
plt.plot(test['y'],c='green',label='actual')
plt.plot(predictions['yhat'],c='red',label='predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation of Models
#
# Judging the models base on the rmse, we can say thet the LSTM model was the best performing model which yields the lowest RMSE. This means that the LSTM model will give us the most reliable predictions.
#
# Our RMSE for the LSTM model tells us that we can expect our close price predictions to be off, on average, by $4.44.

# %%
rmses = pd.Series( [baseline_rmse, arima_rmse, lstm_rmse, fbprophet_rmse], index=['Baseline','ARIMA','LSTM','FBprophet'])
rmses = pd.DataFrame(rmses,columns=['VOO_RMSEs'])
rmses = rmses.reset_index()
rmses.columns = ['Model','VOO_RMSEs']
rmses
# Out:
#        Model  VOO_RMSEs
# 0   Baseline  19.661195
# 1      ARIMA  32.937877
# 2       LSTM   4.440468
# 3  FBprophet  31.302444

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
rmses_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')
rmses_df = rmses_df.drop('Unnamed: 0',axis=1)
rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  DIA_RMSEs  VUG_RMSEs  SPY_RMSEs
# 0   Baseline     1.588590  21.442564  ...  19.163181  14.170785  21.318424
# 1      ARIMA     2.292706  36.026600  ...  20.143136  21.115098  35.735622
# 2       LSTM     0.569077   4.710478  ...   6.561175   4.534771   4.747338
# 3  FBprophet     5.670109  32.488233  ...  24.605617  41.450437  35.484111
#
# [4 rows x 12 columns]

# %%
rmses_df = pd.concat([rmses_df,rmses[['VOO_RMSEs']]],axis=1)
rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  VUG_RMSEs  SPY_RMSEs  VOO_RMSEs
# 0   Baseline     1.588590  21.442564  ...  14.170785  21.318424  19.661195
# 1      ARIMA     2.292706  36.026600  ...  21.115098  35.735622  32.937877
# 2       LSTM     0.569077   4.710478  ...   4.534771   4.747338   4.440468
# 3  FBprophet     5.670109  32.488233  ...  41.450437  35.484111  31.302444
#
# [4 rows x 13 columns]

# %%
rmses_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')

# %% [markdown]
# ### Forecasting Future Closing Prices
#
# Now that we have found our best working model, we will use it to find the next 60 day close prices to and calculate the ROI from the current day to the last forecasted day.

# %%
# next 60 days close price predictions
future_predictions = []

last_60_days = X_test[-1] # real

while len(future_predictions) != 60:
    # reshape the input array for the lstm model
    X = np.reshape(last_60_days, (last_60_days.shape[1], last_60_days.shape[0], 1))
    # make one new prediction
    forecast = model.predict(X) 
    # update last_60_days dropping first value and adding the new prediction to the end of the array
    new = np.concatenate((last_60_days, forecast))
    last_60_days = new[1:]
    # append unscaled prediction to future predictions
    future_predictions.append(scaler.inverse_transform(forecast)[0])

# %%
predictions_df = pd.DataFrame(future_predictions,columns=['close'])
VOO_copy = VOO.copy()
VOO_copy = VOO.reset_index()
VOO_copy['date'] = VOO_copy['date'].apply(lambda x: x.replace(tzinfo=None))
VOO_copy
# Out:
#            date   close
# 0    2017-01-12  208.05
# 1    2017-01-13  208.46
# 2    2017-01-14  207.72
# 3    2017-01-15  207.72
# 4    2017-01-16  207.72
# ...         ...     ...
# 1820 2022-01-06  430.08
# 1821 2022-01-07  428.59
# 1822 2022-01-08  428.03
# 1823 2022-01-09  428.03
# 1824 2022-01-10  428.03
#
# [1825 rows x 2 columns]

# %%
# getting dates for the next 60 days

from datetime import datetime, timedelta

def date_range(start, end):
    delta = end - start  # as timedelta
    days = [start + timedelta(days=i) for i in range(delta.days + 1)]
    return days

# last date from the data
start_date = VOO_copy.iloc[-1,0]

end_date = datetime(2022, 3, 11)
    
future_dates = date_range(start_date, end_date)[1:]

# %%
# Create new dataframe with next 60 day close price predictions 
predictions_df['date'] = future_dates
predictions_df = predictions_df[['date','close']]
VOO_copy_2 = pd.concat([VOO_copy,predictions_df])
# Final dataframe with old data and next 60 day predictions
VOO_copy_2 = VOO_copy_2.set_index('date')

# %%
# Find the ROI for the next 60 days
ROI_next_60_days = (VOO_copy_2.iloc[-1] - VOO_copy_2.iloc[-61]) / VOO_copy_2.iloc[-61]
print(f"Next 60 days ROI: {round(ROI_next_60_days[0]*100,2)}%")
# Out:
# Next 60 days ROI: -23.15%

# %%
roi_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
roi_df = roi_df.drop('Unnamed: 0',axis=1)
roi_df
# Out:
#    NASDX_ROI   IVV_ROI  VFIAX_ROI  ...   DIA_ROI   VUG_ROI   SPY_ROI
# 0  -0.178096 -0.217691  -0.289086  ... -0.416967 -0.243621 -0.213185
#
# [1 rows x 11 columns]

# %%
#roi_df = roi_df.drop('Unnamed: 0',axis=1)
roi_df['VOO_ROI'] = ROI_next_60_days.values

# %%
roi_df
# Out:
#    NASDX_ROI   IVV_ROI  VFIAX_ROI  ...   VUG_ROI   SPY_ROI  VOO_ROI
# 0  -0.178096 -0.217691  -0.289086  ... -0.243621 -0.213185 -0.23154
#
# [1 rows x 12 columns]

# %%
roi_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
