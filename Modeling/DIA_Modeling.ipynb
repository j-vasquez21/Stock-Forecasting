# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
# important to set a keras random seed for reproducibility on the LSTM model
tf.keras.utils.set_random_seed(42)

from keras.models import Sequential
from keras.layers import Dense, LSTM

# Change to statsmodels.tsa.arima.model on jupyter notebook.
# statsmodels.tsa.arima_model for google colab
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from fbprophet import Prophet

import warnings
warnings.simplefilter('ignore')

plt.style.use("fivethirtyeight")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# for working on google colab 
# skip cell if working on jupyter notebook
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8311e114-e007-44a0-b1c8-d6c66423289f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8311e114-e007-44a0-b1c8-d6c66423289f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index_funds_data.csv to index_funds_data.csv

# %% [markdown]
# We begin by importing our funds csv and selecting the data for the ticker name of interest. The price that we will be focusing on will be the Close price of the fund, therefore we will only concern ourselves with the close column. We will also take the opportunity convert the date column into a datetime object.

# %%
funds = pd.read_csv('index_funds_data.csv')
funds['date'] = pd.to_datetime(funds['date'],infer_datetime_format=True)
funds = funds[['symbol','date','close']]
funds = funds.set_index(['symbol','date'])
DIA = funds.loc['DIA',['close']]

# %% [markdown]
# ### Visualize The Closing Price
#
# Below we plot the time series for the fund to get an initial look at what the series looks like.

# %%
plt.figure(figsize=(16,8))
plt.plot(DIA['close'])
plt.title("Close Price History")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.show()

# %% [markdown]
# ### Baseline "Naive" Model

# %% [markdown]
# To set up a baseline model, we shift the time series by 60 days forward. This is known a naive forecast.

# %%
DIA_baseline = DIA.shift(60)
DIA_base_rmse = mean_squared_error(DIA[60:],DIA_baseline[60:],squared=False)
DIA_base_rmse
# Out:
# 18.072817155699408

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.set_title("Baseline Forecast")
ax.plot(DIA,c='b',label='Actual')
ax.plot(DIA_baseline,c='r',label='Baseline')
plt.legend()
plt.show()

# %% [markdown]
# To test the performance of our baseline we decide on a cutoff to split our original time series into the train set and test set. We also split the time series of our baseline using the same cutoff to create a the train predictions and test predictions. Next we calculate the RMSE of the baseline using the test predictions and the actual values, which is the test set from the original time series.

# %%
new_df = pd.DataFrame()
new_df['original'] = DIA['close']
new_df['shifted'] = DIA['close'].shift(60)
cutoff = int(len(new_df['original']) * 0.80)
original = new_df['original']
shifted = new_df['shifted']
original_train, original_test = original[60:cutoff], original[cutoff:]
shifted_train, shifted_test = shifted[60:cutoff], shifted[cutoff:]

# %%
baseline_rmse = mean_squared_error(original_train,shifted_train,squared=False)
baseline_rmse
# Out:
# 19.16318125804198

# %% [markdown]
# To help visualize the results from the baseline, we plot each set below.

# %%
plt.figure(figsize=(10,4))
plt.title('DIA Baseline Forecast')
plt.plot(original_train,label='Train')
plt.plot(original_test,c='r',label='Actual')
plt.plot(shifted_test,c='blue',label='Baseline Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### ARIMA Modeling
# Next, we move on to the next modeling techinique. We have defined various helper functions below to help us with the ARIMA modeling process.
#
# As we recall from the EDA notebook, the time series is not stationary to begin with. Applying differencing was able to convert the time series to a stationary one. So we can expect to have an ARIMA model with at least a first order differencing.

# %%
# Arima Helper Functions

# get all possible combinations of (p,d,q) for a range (n,k)
def get_combos(n,k):
    p = d = q = range(n, k)
    pdq = list(itertools.product(p, d, q))
    pdqs = [(x[0], x[1], x[2]) for x in list(itertools.product(p, d, q))]
    return pdqs

# find the optimal order for arima model for a series
def get_optimal_params(ts,n,k):
    pdq = get_combos(n,k)
    ans = []
    for comb in pdq:
        try:
            model = ARIMA(ts,
                         order=comb)
            output = model.fit()
            ans.append([comb,output.aic])
        except:
            continue
    ans_df = pd.DataFrame(ans, columns=['pdq','aic'])
    optimals = ans_df.loc[ans_df['aic'].idxmin()]
    return optimals

# fit arima model
def arima_models(ts,n,k):
    order = get_optimal_params(ts,n,k)['pdq']
    model = ARIMA(ts,
                 order=order)
    output = model.fit()
    return output

# time series train test split
def train_test_splt(ts,test_size):
    cutoff = int(ts.shape[0]*(1-test_size))
    train = ts[:cutoff]
    test = ts[cutoff:]
    return train, test

def find_rmse(model, test_data):
    y_hat = model.predict(start=test_data.index[0], end=test_data.index[-1], typ='levels')
    return y_hat, np.sqrt(mean_squared_error(test_data, y_hat))

# %%
DIA_train, DIA_test = train_test_splt(DIA,.2)

# Find optimal pdq
print(get_optimal_params(DIA_train,0,3))

# Fit ARIMA with optimal pdq
arima_model = arima_models(DIA_train,0,3)

# Summary of model
arima_model.summary()
# Out:
# pdq    (2, 1, 2)
# aic      6967.32
# Name: 22, dtype: object
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                 1459
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -3477.662
# Method:                       css-mle   S.D. of innovations              2.623
# Date:                Mon, 24 Jan 2022   AIC                           6967.324
# Time:                        07:25:17   BIC                           6999.037
# Sample:                    01-13-2017   HQIC                          6979.155
#                          - 01-10-2021
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0764      0.065      1.171      0.242      -0.052       0.204
# ar.L1.D.close    -1.8330      0.022    -83.508      0.000      -1.876      -1.790
# ar.L2.D.close    -0.9009      0.023    -39.357      0.000      -0.946      -0.856
# ma.L1.D.close     1.7491      0.029     60.083      0.000       1.692       1.806
# ma.L2.D.close     0.7986      0.029     27.626      0.000       0.742       0.855
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0173           -0.2740j            1.0535           -0.4581
# AR.2           -1.0173           +0.2740j            1.0535            0.4581
# MA.1           -1.0951           -0.2301j            1.1190           -0.4670
# MA.2           -1.0951           +0.2301j            1.1190            0.4670
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# Looking at the ARIMA summary table, we can see that the model did in fact apply differencing to our model. Our p-values on our coefficients are low enough, which tell us that they are significant. After an iterative search for the best parameter, this is the best fitting ARIMA model with the lowest AIC score.

# %% [markdown]
# Next we will calculate the RMSE for this model to evaluate it's performance.

# %%
yhat ,arima_rmse = find_rmse(arima_model,DIA_test)

# %%
arima_rmse
# Out:
# 20.14313635539877

# %%
plt.figure(figsize=(15,4))
plt.title('ARIMA model DIA Forecast')
plt.xlabel('Date')
plt.ylabel('Close Price in USD ($)')
plt.plot(DIA_train,c="blue",label='Train')
plt.plot(DIA_test,c='green',label='Actual')
plt.plot(yhat, c='red',label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### LSTM Model

# %% [markdown]
# Our next modeling technique will be the LSTM model. This is a special type of RNN.

# %%
data = DIA.filter(['close'])
dataset = data.values
cutoff = int(len(dataset)*0.8)
cutoff
# Out:
# 1460

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.06943986],
#        [0.06916474],
#        [0.0658083 ],
#        ...,
#        [0.96104325],
#        [0.96104325],
#        [0.96104325]])

# %%
# create scaled training set
train_data = scaled_data[0:cutoff,:]
X_train = []
y_train = []

for i in range(60,len(train_data)):
    X_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])

# %%
# convert X_train and y_train to numpy arrays for training the model
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# reshape X_train for LSTM model
print(X_train.shape)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
# Out:
# (1400, 60)
# (1400, 60, 1)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
# compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model
model.fit(X_train, y_train, batch_size=1,epochs=40)
# Out:
# Epoch 1/40
# 1400/1400 [==============================] - 43s 29ms/step - loss: 0.0013
# Epoch 2/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 6.7779e-04
# Epoch 3/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 4.7430e-04
# Epoch 4/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 4.3879e-04
# Epoch 5/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 4.1504e-04
# Epoch 6/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 4.3150e-04
# Epoch 7/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.7423e-04
# Epoch 8/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 4.1335e-04
# Epoch 9/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 3.8355e-04
# Epoch 10/40
# 1400/1400 [==============================] - 42s 30ms/step - loss: 3.9661e-04
# Epoch 11/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 3.5652e-04
# Epoch 12/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.8521e-04
# Epoch 13/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.7400e-04
# Epoch 14/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.6105e-04
# Epoch 15/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 3.5622e-04
# Epoch 16/40
# 1400/1400 [==============================] - 41s 29ms/step - loss: 3.9048e-04
# Epoch 17/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.2819e-04
# Epoch 18/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.5773e-04
# Epoch 19/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.3166e-04
# Epoch 20/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.5051e-04
# Epoch 21/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.2001e-04
# Epoch 22/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.1502e-04
# Epoch 23/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.0587e-04
# Epoch 24/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.4034e-04
# Epoch 25/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.1900e-04
# Epoch 26/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.3172e-04
# Epoch 27/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.0908e-04
# Epoch 28/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.1259e-04
# Epoch 29/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.2378e-04
# Epoch 30/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.1437e-04
# Epoch 31/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 2.9995e-04
# Epoch 32/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.1210e-04
# Epoch 33/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 3.0373e-04
# Epoch 34/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.1056e-04
# Epoch 35/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 2.8841e-04
# Epoch 36/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.1510e-04
# Epoch 37/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 3.0462e-04
# Epoch 38/40
# 1400/1400 [==============================] - 39s 28ms/step - loss: 2.9879e-04
# Epoch 39/40
# 1400/1400 [==============================] - 40s 28ms/step - loss: 2.9833e-04
# Epoch 40/40
# 1400/1400 [==============================] - 40s 29ms/step - loss: 3.0242e-04

# %%
# creating test data
test_data = scaled_data[cutoff-60:,:]
X_test = []
y_test = dataset[cutoff:,:]

for i in range(60,len(test_data)):
    X_test.append(test_data[i-60:i, 0])

# %%
# convert X_test to numpy array
X_test = np.array(X_test)

# %%
# reshape X_test for LSTM model
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# get model preds
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# %%
# get rmse
lstm_rmse = mean_squared_error(y_test,predictions,squared=False)
lstm_rmse
# Out:
# 6.561174937609103

# %%
# plot the data
train = data[:cutoff]
actual = data[cutoff:]

actual['Predictions'] = predictions

# %%
# visualize 
plt.figure(figsize=(16,8))
plt.title("Model Forecast For DIA")
plt.xlabel("Date",fontsize=18)
plt.ylabel("Close Price in USD ($)",fontsize=18)
plt.plot(train['close'])
plt.plot(actual['close'])
plt.plot(actual['Predictions'])
plt.legend(['Train','Actual','Predictions'],loc='lower right')
plt.show()

# %% [markdown]
# ### FBprophet Model

# %%
# Fbprophet Helper functions

# formats dataframe to meet fbprophet requirements
def prep_dataframe(df):
    ts = df.copy()
    ts.rename(columns={'close':'y'},inplace=True)
    ts.index.name = 'ds'
    ts = ts.reset_index()
    ts['ds'] = ts['ds'].apply(lambda x: x.replace(tzinfo=None))
    return ts

# creates training and test set and fit the prophet model
def fit_train(data,prepared=True):
    # Format dataframe to fbprophet requirements in not already done
    if prepared == False:
        data = prep_dataframe(data)

    # Train-Test Split
    cutoff = int(data.shape[0] * 0.80)
    train = data.iloc[:cutoff]
    test = data.iloc[cutoff:]

    # Fit the model
    mod = Prophet(interval_width=0.95,weekly_seasonality=True,daily_seasonality=True)
    fitted_mod = mod.fit(train)

    if prepared == False:
        return fitted_mod, data, train, test
    else:
        return fitted_mod, train, test

# creates predictions using fitted model
def get_preds(model,test_data):
    preds = model.predict(test_data[['ds']])
    return preds[['ds','yhat_lower','yhat_upper','yhat']]

def get_rmse(preds, test_data):
    return mean_squared_error(preds['yhat'],test_data['y'],squared=False)

# %%
mod, DIA_prepped, train, test = fit_train(DIA,False)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
predictions = get_preds(mod,test)

# %%
fbprophet_rmse = get_rmse(predictions,test)

# %%
fbprophet_rmse
# Out:
# 24.60561681951655

# %%
train = train.set_index('ds')
test = test.set_index('ds')

# %%
predictions = predictions[['ds','yhat']].set_index('ds')

# %%
plt.figure(figsize=(15,5))
plt.title('FBprophet Forecast For DIA')
plt.xlabel('Date')
plt.ylabel("Close Price in USD ($)")
plt.plot(train['y'],label="train")
plt.plot(test['y'],c='green',label='actual')
plt.plot(predictions['yhat'],c='red',label='predictions')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation of Models
#
# Judging the models base on the rmse, we can say thet the LSTM model was the best performing model which yields the lowest RMSE. This means that the LSTM model will give us the most reliable predictions.
#
# Our RMSE for the LSTM model tells us that we can expect our close price predictions to be off, on average, by $6.56.

# %%
rmses = pd.Series( [baseline_rmse, arima_rmse, lstm_rmse, fbprophet_rmse], index=['Baseline','ARIMA','LSTM','FBprophet'])
rmses = pd.DataFrame(rmses,columns=['DIA_RMSEs'])
rmses = rmses.reset_index()
rmses.columns = ['Model','DIA_RMSEs']
rmses
# Out:
#        Model  DIA_RMSEs
# 0   Baseline  19.163181
# 1      ARIMA  20.143136
# 2       LSTM   6.561175
# 3  FBprophet  24.605617

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
rmses_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')
rmses_df = rmses_df.drop('Unnamed: 0',axis=1)
rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  SWPPX_RMSEs  SWTSX_RMSEs  FXAIX_RMSEs
# 0   Baseline     1.588590  21.442564  ...     3.267562     3.917987     7.390902
# 1      ARIMA     2.292706  36.026600  ...     5.890846     5.779298    12.634809
# 2       LSTM     0.569077   4.710478  ...     1.023475     1.108364     2.023572
# 3  FBprophet     5.670109  32.488233  ...     5.617840     7.457487    11.723050
#
# [4 rows x 9 columns]

# %%
rmses_df = pd.concat([rmses_df,rmses[['DIA_RMSEs']]],axis=1)
rmses_df
# Out:
#        Model  NASDX_RMSEs  IVV_RMSEs  ...  SWTSX_RMSEs  FXAIX_RMSEs  DIA_RMSEs
# 0   Baseline     1.588590  21.442564  ...     3.917987     7.390902  19.163181
# 1      ARIMA     2.292706  36.026600  ...     5.779298    12.634809  20.143136
# 2       LSTM     0.569077   4.710478  ...     1.108364     2.023572   6.561175
# 3  FBprophet     5.670109  32.488233  ...     7.457487    11.723050  24.605617
#
# [4 rows x 10 columns]

# %%
rmses_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/model_rmses.csv')

# %% [markdown]
# ### Forecasting Future Closing Prices
#
# Now that we have found our best working model, we will use it to find the next 60 day close prices to and calculate the ROI from the current day to the last forecasted day.

# %%
# next 60 days close price predictions
future_predictions = []

last_60_days = X_test[-1] # real

while len(future_predictions) != 60:
    # reshape the input array for the lstm model
    X = np.reshape(last_60_days, (last_60_days.shape[1], last_60_days.shape[0], 1))
    # make one new prediction
    forecast = model.predict(X) 
    # update last_60_days dropping first value and adding the new prediction to the end of the array
    new = np.concatenate((last_60_days, forecast))
    last_60_days = new[1:]
    # append unscaled prediction to future predictions
    future_predictions.append(scaler.inverse_transform(forecast)[0])

# %%
predictions_df = pd.DataFrame(future_predictions,columns=['close'])
DIA_copy = DIA.copy()
DIA_copy = DIA.reset_index()
DIA_copy['date'] = DIA_copy['date'].apply(lambda x: x.replace(tzinfo=None))
DIA_copy
# Out:
#            date   close
# 0    2017-01-12  198.75
# 1    2017-01-13  198.70
# 2    2017-01-14  198.09
# 3    2017-01-15  198.09
# 4    2017-01-16  198.09
# ...         ...     ...
# 1820 2022-01-06  362.39
# 1821 2022-01-07  362.31
# 1822 2022-01-08  360.79
# 1823 2022-01-09  360.79
# 1824 2022-01-10  360.79
#
# [1825 rows x 2 columns]

# %%
# getting dates for the next 60 days

from datetime import datetime, timedelta

def date_range(start, end):
    delta = end - start  # as timedelta
    days = [start + timedelta(days=i) for i in range(delta.days + 1)]
    return days

# last date from the data
start_date = DIA_copy.iloc[-1,0]

end_date = datetime(2022, 3, 11)
    
future_dates = date_range(start_date, end_date)[1:]

# %%
# Create new dataframe with next 60 day close price predictions 
predictions_df['date'] = future_dates
predictions_df = predictions_df[['date','close']]
DIA_copy_2 = pd.concat([DIA_copy,predictions_df])
# Final dataframe with old data and next 60 day predictions
DIA_copy_2 = DIA_copy_2.set_index('date')

# %%
# Find the ROI for the next 60 days
ROI_next_60_days = (DIA_copy_2.iloc[-1] - DIA_copy_2.iloc[-61]) / DIA_copy_2.iloc[-61]
print(f"Next 60 days ROI: {round(ROI_next_60_days[0]*100,2)}%")
# Out:
# Next 60 days ROI: -41.7%

# %%
roi_df = pd.read_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
roi_df = roi_df.drop('Unnamed: 0',axis=1)
roi_df
# Out:
#    NASDX_ROI   IVV_ROI  VFIAX_ROI  ...  SWPPX_ROI  SWTSX_ROI  FXAIX_ROI
# 0  -0.178096 -0.217691  -0.289086  ...  -0.326752  -0.252235  -0.274636
#
# [1 rows x 8 columns]

# %%
#roi_df = roi_df.drop('Unnamed: 0',axis=1)
roi_df['DIA_ROI'] = ROI_next_60_days.values

# %%
roi_df
# Out:
#    NASDX_ROI   IVV_ROI  VFIAX_ROI  ...  SWTSX_ROI  FXAIX_ROI   DIA_ROI
# 0  -0.178096 -0.217691  -0.289086  ...  -0.252235  -0.274636 -0.416967
#
# [1 rows x 9 columns]

# %%
roi_df.to_csv('/drive/My Drive/Stock_Forecasting/Modeling/rois.csv')
